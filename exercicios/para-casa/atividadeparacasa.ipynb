# %%
import pandas as pd

df = pd.read_csv('sao paulo.CSV', delimiter=';', skiprows=8,encoding='latin1')

# %%
df_saopaulo = df.sample(n=20)

# %%
df_saopaulo.head()
# Out:
#             Data  Hora UTC PRECIPITAÇÃO TOTAL, HORÁRIO (mm)  \
# 4560  09/07/2020  0000 UTC                                0
# 7192  26/10/2020  1600 UTC                                0
# 7396  04/11/2020  0400 UTC                                0
# 5219  05/08/2020  1100 UTC                                0
# 4460  04/07/2020  2000 UTC                                0
#
#      PRESSAO ATMOSFERICA AO NIVEL DA ESTACAO, HORARIA (mB)  \
# 4560                                                926
# 7192                                              923,3
# 7396                                              927,2
# 5219                                              938,2
# 4460                                              927,8
#
#      PRESSÃO ATMOSFERICA MAX.NA HORA ANT. (AUT) (mB)  \
# 4560                                             926
# 7192                                           924,2
# 7396                                             928
# ...

# %%
coluna_temperatura_maxima = df['TEMPERATURA MÁXIMA NA HORA ANT. (AUT) (°C)']

# %%
coluna_temperatura_maxima = pd.to_numeric(df['TEMPERATURA MÁXIMA NA HORA ANT. (AUT) (°C)'], errors='coerce')

# %%
coluna_temperatura_maxima.mean()
# Out:
# np.float64(20.114754098360656)

# %%
coluna_radiacao_global = df['RADIACAO GLOBAL (Kj/m²)']

# %%
coluna_radiacao_global.head()
# Out:
# 0    NaN
# 1    NaN
# 2    NaN
# 3    NaN
# 4    NaN
# Name: RADIACAO GLOBAL (Kj/m²), dtype: object

# %%
df.isnull()
# Out:
#        Data  Hora UTC  PRECIPITAÇÃO TOTAL, HORÁRIO (mm)  \
# 0     False     False                             False
# 1     False     False                             False
# 2     False     False                             False
# 3     False     False                             False
# 4     False     False                             False
# ...     ...       ...                               ...
# 8779  False     False                             False
# 8780  False     False                             False
# 8781  False     False                             False
# 8782  False     False                             False
# 8783  False     False                             False
#
#       PRESSAO ATMOSFERICA AO NIVEL DA ESTACAO, HORARIA (mB)  \
# 0                                                 False
# 1                                                 False
# 2                                                 False
# 3                                                 False
# ...

# %%
df.dropna()
# Out:
#             Data  Hora UTC PRECIPITAÇÃO TOTAL, HORÁRIO (mm)  \
# 9     01/01/2020  0900 UTC                                0
# 10    01/01/2020  1000 UTC                                0
# 11    01/01/2020  1100 UTC                                0
# 12    01/01/2020  1200 UTC                                0
# 13    01/01/2020  1300 UTC                                0
# ...          ...       ...                              ...
# 8778  31/12/2020  1800 UTC                                0
# 8779  31/12/2020  1900 UTC                                0
# 8780  31/12/2020  2000 UTC                                0
# 8781  31/12/2020  2100 UTC                              0,8
# 8782  31/12/2020  2200 UTC                              9,2
#
#      PRESSAO ATMOSFERICA AO NIVEL DA ESTACAO, HORARIA (mB)  \
# 9                                                 922,3
# 10                                                922,5
# 11                                                922,9
# ...

# %%
df_reduzido  = df[['Data', 'PRECIPITAÇÃO TOTAL, HORÁRIO (mm)', 'TEMPERATURA DO PONTO DE ORVALHO (°C)']]

# %%
df_reduzido.head(1000)
# Out:
#            Data PRECIPITAÇÃO TOTAL, HORÁRIO (mm)  \
# 0    01/01/2020                                0
# 1    01/01/2020                                0
# 2    01/01/2020                                0
# 3    01/01/2020                                0
# 4    01/01/2020                                0
# ..          ...                              ...
# 995  11/02/2020                              0,2
# 996  11/02/2020                              0,2
# 997  11/02/2020                                0
# 998  11/02/2020                                0
# 999  11/02/2020                                0
#
#     TEMPERATURA DO PONTO DE ORVALHO (°C)
# 0                                   20,5
# 1                                   20,7
# 2                                   20,1
# 3                                   19,5
# 4                                     19
# ..                                   ...
# 995                                 16,3
# ...

# %%
df_substituido = df.replace('0', '20')

# %%
df_substituido.head(10)
# Out:
#          Data  Hora UTC PRECIPITAÇÃO TOTAL, HORÁRIO (mm)  \
# 0  01/01/2020  0000 UTC                               20
# 1  01/01/2020  0100 UTC                               20
# 2  01/01/2020  0200 UTC                               20
# 3  01/01/2020  0300 UTC                               20
# 4  01/01/2020  0400 UTC                               20
# 5  01/01/2020  0500 UTC                               20
# 6  01/01/2020  0600 UTC                               20
# 7  01/01/2020  0700 UTC                               20
# 8  01/01/2020  0800 UTC                               20
# 9  01/01/2020  0900 UTC                               20
#
#   PRESSAO ATMOSFERICA AO NIVEL DA ESTACAO, HORARIA (mB)  \
# 0                                              923,1
# 1                                              923,7
# 2                                              923,6
# 3                                              923,1
# 4                                              922,6
# ...
