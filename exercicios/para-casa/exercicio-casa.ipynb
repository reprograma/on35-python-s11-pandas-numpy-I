# %% [markdown]
# ### **Exercicios Para Casa**
#
#
# *Utilizar a tabela de dados do clima de seu estado, manipule os dados de acordo com as instruções abaixo:*

# %%
import pandas as pd

df = pd.read_csv('SP-2023.CSV', delimiter=';', skiprows=8, encoding='latin1')

# %%
df.head()
# Out:
#          Data  Hora UTC PRECIPITAÇÃO TOTAL, HORÁRIO (mm)  \
# 0  2023/01/01  0000 UTC                                0
# 1  2023/01/01  0100 UTC                                0
# 2  2023/01/01  0200 UTC                                0
# 3  2023/01/01  0300 UTC                                0
# 4  2023/01/01  0400 UTC                                0
#
#   PRESSAO ATMOSFERICA AO NIVEL DA ESTACAO, HORARIA (mB)  \
# 0                                              927,2
# 1                                              927,2
# 2                                              927,1
# 3                                              926,6
# 4                                              925,7
#
#   PRESSÃO ATMOSFERICA MAX.NA HORA ANT. (AUT) (mB)  \
# 0                                           927,2
# 1                                           927,2
# 2                                           927,3
# 3                                           927,1
# ...

# %% [markdown]
# ### **Calcular a média da temperatura da amostra**

# %%
umidade_maxima = df['UMIDADE REL. MAX. NA HORA ANT. (AUT) (%)']

# %%
umidade_maxima.mean()
# Out:
# np.float64(71.24906367041199)

# %% [markdown]
# ### **Retirar nulos da coluna RADIACAO GLOBAL (Kj/m2)**

# %%
df.head()
# Out:
#          Data  Hora UTC PRECIPITAÇÃO TOTAL, HORÁRIO (mm)  \
# 0  2023/01/01  0000 UTC                                0
# 1  2023/01/01  0100 UTC                                0
# 2  2023/01/01  0200 UTC                                0
# 3  2023/01/01  0300 UTC                                0
# 4  2023/01/01  0400 UTC                                0
#
#   PRESSAO ATMOSFERICA AO NIVEL DA ESTACAO, HORARIA (mB)  \
# 0                                              927,2
# 1                                              927,2
# 2                                              927,1
# 3                                              926,6
# 4                                              925,7
#
#   PRESSÃO ATMOSFERICA MAX.NA HORA ANT. (AUT) (mB)  \
# 0                                           927,2
# 1                                           927,2
# 2                                           927,3
# 3                                           927,1
# ...

# %%
df_sem_nulo = df.dropna(subset=['RADIACAO GLOBAL (Kj/m²)'])
df_sem_nulo
# Out:
#             Data  Hora UTC PRECIPITAÇÃO TOTAL, HORÁRIO (mm)  \
# 9     2023/01/01  0900 UTC                                0
# 10    2023/01/01  1000 UTC                                0
# 11    2023/01/01  1100 UTC                                0
# 12    2023/01/01  1200 UTC                                0
# 13    2023/01/01  1300 UTC                                0
# ...          ...       ...                              ...
# 8754  2023/12/31  1800 UTC                                0
# 8755  2023/12/31  1900 UTC                                0
# 8756  2023/12/31  2000 UTC                                0
# 8757  2023/12/31  2100 UTC                                0
# 8758  2023/12/31  2200 UTC                                0
#
#      PRESSAO ATMOSFERICA AO NIVEL DA ESTACAO, HORARIA (mB)  \
# 9                                                 926,3
# 10                                                  927
# 11                                                927,5
# ...

# %% [markdown]
# ### **Copiar o dataframe reduzindo para 3 colunas (a sua escolha) e 1000 linhas (aleatórias)**

# %%
df_reduzido  = df[['Data', 'TEMPERATURA MÍNIMA NA HORA ANT. (AUT) (°C)', 'TEMPERATURA MÁXIMA NA HORA ANT. (AUT) (°C)']]
df_reduzido.sample(1000)
# Out:
#             Data TEMPERATURA MÍNIMA NA HORA ANT. (AUT) (°C)  \
# 8553  2023/12/23                                       20,9
# 1648  2023/03/10                                       27,3
# 2671  2023/04/22                                       13,9
# 5960  2023/09/06                                       16,2
# 2321  2023/04/07                                       21,9
# ...          ...                                        ...
# 2082  2023/03/28                                       25,7
# 7265  2023/10/30                                       28,6
# 6395  2023/09/24                                       23,2
# 5011  2023/07/28                                       25,6
# 1530  2023/03/05                                       26,2
#
#      TEMPERATURA MÁXIMA NA HORA ANT. (AUT) (°C)
# 8553                                       21,7
# 1648                                       31,1
# 2671                                       14,1
# 5960                                       16,3
# ...

# %% [markdown]
# ### **Bônus: Normalizar coluna (qualquer uma)**

# %%
df_reduzido_temperatura = pd.to_numeric(df['TEMPERATURA MÍNIMA NA HORA ANT. (AUT) (°C)'].replace(',', '.', regex=True), errors='coerce')

# %%
df_reduzido_temperatura
# Out:
# 0       20.2
# 1       20.1
# 2       20.2
# 3       20.3
# 4       19.8
#         ...
# 8755    22.6
# 8756    21.2
# 8757    21.1
# 8758    20.3
# 8759    19.8
# Name: TEMPERATURA MÍNIMA NA HORA ANT. (AUT) (°C), Length: 8760, dtype: float64

# %% [markdown]
# ### **Bônus II: Pesquisar sobre outras formas de processamento de dados além das vistas em sala de aula**

# %% [markdown]
# **DataFrame.nunique:** Contar o número de elementos distintos no eixo especificado.

# %%
df.nunique()
# Out:
# Data                                                      365
# Hora UTC                                                   24
# PRECIPITAÇÃO TOTAL, HORÁRIO (mm)                           84
# PRESSAO ATMOSFERICA AO NIVEL DA ESTACAO, HORARIA (mB)     232
# PRESSÃO ATMOSFERICA MAX.NA HORA ANT. (AUT) (mB)           226
# PRESSÃO ATMOSFERICA MIN. NA HORA ANT. (AUT) (mB)          230
# RADIACAO GLOBAL (Kj/m²)                                  4081
# TEMPERATURA DO AR - BULBO SECO, HORARIA (°C)              259
# TEMPERATURA DO PONTO DE ORVALHO (°C)                      197
# TEMPERATURA MÁXIMA NA HORA ANT. (AUT) (°C)                267
# TEMPERATURA MÍNIMA NA HORA ANT. (AUT) (°C)                256
# TEMPERATURA ORVALHO MAX. NA HORA ANT. (AUT) (°C)          184
# TEMPERATURA ORVALHO MIN. NA HORA ANT. (AUT) (°C)          200
# UMIDADE REL. MAX. NA HORA ANT. (AUT) (%)                   82
# UMIDADE REL. MIN. NA HORA ANT. (AUT) (%)                   85
# ...

# %%
df_reduzido.T
# Out:
#                                                   0           1     \
# Data                                        2023/01/01  2023/01/01
# TEMPERATURA MÍNIMA NA HORA ANT. (AUT) (°C)        20,2        20,1
# TEMPERATURA MÁXIMA NA HORA ANT. (AUT) (°C)        20,5        20,4
#
#                                                   2           3     \
# Data                                        2023/01/01  2023/01/01
# TEMPERATURA MÍNIMA NA HORA ANT. (AUT) (°C)        20,2        20,3
# TEMPERATURA MÁXIMA NA HORA ANT. (AUT) (°C)        20,6        20,6
#
#                                                   4           5     \
# Data                                        2023/01/01  2023/01/01
# TEMPERATURA MÍNIMA NA HORA ANT. (AUT) (°C)        19,8        19,2
# TEMPERATURA MÁXIMA NA HORA ANT. (AUT) (°C)        20,4        19,9
#
#                                                   6           7     \
# Data                                        2023/01/01  2023/01/01
# ...
