# %%
import pandas as pd
import numpy as np

# %% [markdown]
#  - calcular a média da temperatura da amostra
#     - retirar nulos da coluna 'RADIACAO GLOBAL (Kj/m2)'
#     - copiar o dataframe reduzindo para 3 colunas (a sua escolha) e 1000 linhas (aleatórias)
#     - Bônus: normalizar coluna (qualquer uma)
#     - Bônus II: pesquisar sobre outras formas de processamento de dados além das vistas em sala de aula

# %%
#ler o arquivo
df= pd.read_csv('recife-2021.CSV', delimiter=';', skiprows=8, encoding='latin1')

# %%
df.head()
# Out:
#          Data  Hora UTC PRECIPITAÇÃO TOTAL, HORÁRIO (mm)  \
# 0  2021/01/01  0000 UTC                                0
# 1  2021/01/01  0100 UTC                                0
# 2  2021/01/01  0200 UTC                                0
# 3  2021/01/01  0300 UTC                              1,2
# 4  2021/01/01  0400 UTC                                0
#
#   PRESSAO ATMOSFERICA AO NIVEL DA ESTACAO, HORARIA (mB)  \
# 0                                             1013,2
# 1                                             1013,3
# 2                                             1012,8
# 3                                             1012,5
# 4                                             1011,8
#
#   PRESSÃO ATMOSFERICA MAX.NA HORA ANT. (AUT) (mB)  \
# 0                                          1013,2
# 1                                          1013,4
# 2                                          1013,3
# 3                                          1012,8
# ...

# %%
#Retirar nulos da coluna Temperatura do ar
df_reduzidot = df.dropna(subset=['TEMPERATURA DO AR - BULBO SECO, HORARIA (°C)'])
df_reduzidot
# Out:
#             Data  Hora UTC PRECIPITAÇÃO TOTAL, HORÁRIO (mm)  \
# 0     2021/01/01  0000 UTC                                0
# 1     2021/01/01  0100 UTC                                0
# 2     2021/01/01  0200 UTC                                0
# 3     2021/01/01  0300 UTC                              1,2
# 4     2021/01/01  0400 UTC                                0
# ...          ...       ...                              ...
# 7562  2021/11/12  0200 UTC                                0
# 7563  2021/11/12  0300 UTC                                0
# 7564  2021/11/12  0400 UTC                               ,6
# 7565  2021/11/12  0500 UTC                               ,2
# 7566  2021/11/12  0600 UTC                               ,2
#
#      PRESSAO ATMOSFERICA AO NIVEL DA ESTACAO, HORARIA (mB)  \
# 0                                                1013,2
# 1                                                1013,3
# 2                                                1012,8
# ...

# %%
df_reduzidot = pd.to_numeric(df_reduzidot['TEMPERATURA DO AR - BULBO SECO, HORARIA (°C)'], errors='coerce')
df_reduzidot
# Out:
# 0      NaN
# 1      NaN
# 2      NaN
# 3      NaN
# 4      NaN
#         ..
# 7562   NaN
# 7563   NaN
# 7564   NaN
# 7565   NaN
# 7566   NaN
# Name: TEMPERATURA DO AR - BULBO SECO, HORARIA (°C), Length: 7551, dtype: float64

# %%
#Retirar nulos da coluna RADIACAO GLOBAL
df_reduzido = df.dropna(subset=['RADIACAO GLOBAL (Kj/m²)'])
df_reduzido
# Out:
#             Data  Hora UTC PRECIPITAÇÃO TOTAL, HORÁRIO (mm)  \
# 9     2021/01/01  0900 UTC                                0
# 10    2021/01/01  1000 UTC                                0
# 11    2021/01/01  1100 UTC                                0
# 12    2021/01/01  1200 UTC                                0
# 13    2021/01/01  1300 UTC                                0
# ...          ...       ...                              ...
# 7553  2021/11/11  1700 UTC                                0
# 7554  2021/11/11  1800 UTC                                0
# 7555  2021/11/11  1900 UTC                                0
# 7556  2021/11/11  2000 UTC                                0
# 7557  2021/11/11  2100 UTC                                0
#
#      PRESSAO ATMOSFERICA AO NIVEL DA ESTACAO, HORARIA (mB)  \
# 9                                                  1013
# 10                                               1013,3
# 11                                               1013,5
# ...

# %%
#Quantidade de nulos antes
nulos_antes = df['RADIACAO GLOBAL (Kj/m²)'].isnull().sum()
print("Quantidade de nulos antes da remoçao: ",nulos_antes)
# Out:
# Quantidade de nulos antes da remoçao:  4644

# %%
#Quantidade de nulos depois da remoçao
nulos_depois = df_reduzido['RADIACAO GLOBAL (Kj/m²)'].isnull().sum()
print("Quantidade de nulos depois da remoçao: ",nulos_depois)
# Out:
# Quantidade de nulos depois da remoçao:  0

# %%
#reduzindo para 3 colunas e 1000 linhas (aleatórias) 
df_reduzido = df[['Data', 'TEMPERATURA MÁXIMA NA HORA ANT. (AUT) (°C)', 'TEMPERATURA DO AR - BULBO SECO, HORARIA (°C)' ]].sample(n=1000)
df_reduzido.head(1000)
# Out:
#             Data TEMPERATURA MÁXIMA NA HORA ANT. (AUT) (°C)  \
# 6306  2021/09/20                                       29,1
# 5515  2021/08/18                                       26,5
# 4781  2021/07/19                                       21,8
# 7255  2021/10/30                                         21
# 8141  2021/12/06                                        NaN
# ...          ...                                        ...
# 2728  2021/04/24                                       31,2
# 4749  2021/07/17                                       23,6
# 1096  2021/02/15                                       27,9
# 527   2021/01/22                                       26,7
# 2059  2021/03/27                                         28
#
#      TEMPERATURA DO AR - BULBO SECO, HORARIA (°C)
# 6306                                         27,2
# 5515                                         24,8
# 4781                                         21,6
# ...
