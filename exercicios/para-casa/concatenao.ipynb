# %%
import pandas as pd
import os

path="praticando/importar/"
files = os.listdir(path)

dfs = []

for i in files:
    dfs.append(files)

# %%
date='1408'

df_cdba = pd.read_csv(f'{path}{dfs[0][0]}',delimiter=';', encoding='latin1')
df_cdneos = pd.read_csv(f'{path}{dfs[0][1]}',delimiter=';', encoding='latin1')
df_cdpe = pd.read_csv(f'{path}{dfs[0][2]}',delimiter=';', encoding='latin1')
df_cdrn = pd.read_csv(f'{path}{dfs[0][3]}',delimiter=';', encoding='latin1')

# %%
df_cdba = (df_cdba[['Cliente','Código','Cotação','Quantidade Total']].dropna(axis=0))
df_cdneos = (df_cdneos[['Cliente','Código','Cotação','Quantidade Total']].dropna(axis=0))
df_cdpe = (df_cdpe[['Cliente','Código','Cotação','Quantidade Total']].dropna(axis=0))
df_cdrn = (df_cdrn[['Cliente','Código','Cotação','Quantidade Total']].dropna(axis=0))

# %%
dfs = pd.concat([df_cdba,df_cdneos,df_cdpe,df_cdrn]).reset_index(drop='True') #axis = 0 -> linhas
dfs
# Out:
#             Cliente    Código          Cotação      Quantidade Total
# 0   CUST0207         CUST0970      25,82869639    7.028.168,01954160
# 1   CUST0207         CUST1190       2,23259433  146.839.413,35566800
# 2   CUST0207         CUST1192       2,36069502   42.314.229,24087930
# 3   CUST0207         CUST2315       1,10598782   22.048.514,13859530
# 4   CUST0207         CUST3075       1,20126644   73.961.661,22542130
# 5   CUST0207         CUST3081       1,11953438   72.716.409,24649740
# 6   CUST0207         TCUS0349  13.268,40421089          223,67755270
# 7   CUST0207         TCUS0646  16.858,34032199          243,13447753
# 8   CUST0207         TFBR0308       1,57914690    7.274.663,39078412
# 9   CUST0207         TFBT0875       1,30131880    7.756.702,34152928
# 10  CUST0207         TFGE0014  16.858,34032199          522,04050064
# 11  CUST0207         TFML2226       2,25605384   15.955.103,10631320
# 12  CUST1903         CUST0970      25,82869639    7.848.954,24687267
# ...

# %%
df_consolidado_excel = dfs.to_excel(f'{path}cds.xlsx')

# %%
df_consolidado_csv = dfs.to_excel(f'{path}cds.xlsx')

# %%
for i in files:
    if 'CDBA' in files:
        df_cdba = pd.read_csv(f'{path}CARTEIRADIARIA_CDBA_{date}.csv',delimiter=';', encoding='latin1')
    # elif 'CDPE':
    #     df_cdpe = pd.read_csv(f'{path}CARTEIRADIARIA_CDPE_{date}.csv',delimiter=';', encoding='latin1')
    # elif 'CDNEOS':
    #     df_cdneos = pd.read_csv('f{path}CARTEIRADIARIA_CDNEOS_{date}.csv',delimiter=';', encoding='latin1')
    # elif 'RN':
    #     df_cdrn = pd.read_csv('f{path}CARTEIRADIARIA_CDRN_{date}.csv',delimiter=';', encoding='latin1')
    i+=1
df_cdba
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[47], line 10
#       3         df_cdba = pd.read_csv(f'{path}CARTEIRADIARIA_CDBA_{date}.csv',delimiter=';', encoding='latin1')
#       4     # elif 'CDPE':
#       5     #     df_cdpe = pd.read_csv(f'{path}CARTEIRADIARIA_CDPE_{date}.csv',delimiter=';', encoding='latin1')
#       6     # elif 'CDNEOS':
#       7     #     df_cdneos = pd.read_csv('f{path}CARTEIRADIARIA_CDNEOS_{date}.csv',delimiter=';', encoding='latin1')
#       8     # elif 'RN':
#       9     #     df_cdrn = pd.read_csv('f{path}CARTEIRADIARIA_CDRN_{date}.csv',delimiter=';', encoding='latin1')
# ---> 10     i+=1
#      11 df_cdba
#
# TypeError: can only concatenate str (not "int") to str

# %%
df_cdba = (df_cdba[['Cliente','Código','Cotação','Quantidade Total']].dropna(axis=0))
# df_cdneos = (df_cdneos[['Cliente','Código','Cotação','Quantidade Total']].dropna(axis=0))
# df_cdpe = (df_cdneos[['Cliente','Código','Cotação','Quantidade Total']].dropna(axis=0))
# df_cdrn = (df_cdrn[['Cliente','Código','Cotação','Quantidade Total']].dropna(axis=0))

# %%
df = df.rename(columns={'Cotação':'Valor Cota'})
df
# Out:
#             Cliente    Código       Valor Cota      Quantidade Total
# 0   CUST0207         CUST0970      25,82869639    7.028.168,01954160
# 1   CUST0207         CUST1190       2,23259433  146.839.413,35566800
# 2   CUST0207         CUST1192       2,36069502   42.314.229,24087930
# 3   CUST0207         CUST2315       1,10598782   22.048.514,13859530
# 4   CUST0207         CUST3075       1,20126644   73.961.661,22542130
# 5   CUST0207         CUST3081       1,11953438   72.716.409,24649740
# 6   CUST0207         TCUS0349  13.268,40421089          223,67755270
# 7   CUST0207         TCUS0646  16.858,34032199          243,13447753
# 8   CUST0207         TFBR0308       1,57914690    7.274.663,39078412
# 9   CUST0207         TFBT0875       1,30131880    7.756.702,34152928
# 10  CUST0207         TFGE0014  16.858,34032199          522,04050064
# 11  CUST0207         TFML2226       2,25605384   15.955.103,10631320
