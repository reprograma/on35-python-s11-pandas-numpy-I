# %%
import pandas as pd

# %%
df = pd.read_csv('sao_paulo_2023.CSV', delimiter=';', skiprows=8, encoding='latin1')

# %%
df.head()
# Out:
#          Data  Hora UTC PRECIPITAÇÃO TOTAL, HORÁRIO (mm)  \
# 0  2023/01/01  0000 UTC                                0
# 1  2023/01/01  0100 UTC                                0
# 2  2023/01/01  0200 UTC                                0
# 3  2023/01/01  0300 UTC                                0
# 4  2023/01/01  0400 UTC                                0
#
#   PRESSAO ATMOSFERICA AO NIVEL DA ESTACAO, HORARIA (mB)  \
# 0                                              927,2
# 1                                              927,2
# 2                                              927,1
# 3                                              926,6
# 4                                              925,7
#
#   PRESSÃO ATMOSFERICA MAX.NA HORA ANT. (AUT) (mB)  \
# 0                                           927,2
# 1                                           927,2
# 2                                           927,3
# 3                                           927,1
# ...

# %% [markdown]
# 1. Calcular a média da temperatura da amostra

# %%
coluna_temperatura_media =df['TEMPERATURA DO AR - BULBO SECO, HORARIA (°C)']

# %%
coluna_temperatura_media.mean
# Out:
# <bound method Series.mean of 0       20,3
# 1       20,2
# 2       20,6
# 3       20,4
# 4       19,8
#         ...
# 8755    23,8
# 8756    21,2
# 8757    21,2
# 8758    20,4
# 8759    19,9
# Name: TEMPERATURA DO AR - BULBO SECO, HORARIA (°C), Length: 8760, dtype: object>

# %% [markdown]
# 2. retirar nulos da coluna 'RADIACAO GLOBAL (Kj/m2)'

# %%
import numpy as np

# %%
from pandas import Series, DataFrame

# %%
coluna_radiacao_global =df['RADIACAO GLOBAL (Kj/m²)']

# %%
df.isnull().sum()
# Out:
# Data                                                        0
# Hora UTC                                                    0
# PRECIPITAÇÃO TOTAL, HORÁRIO (mm)                          645
# PRESSAO ATMOSFERICA AO NIVEL DA ESTACAO, HORARIA (mB)     212
# PRESSÃO ATMOSFERICA MAX.NA HORA ANT. (AUT) (mB)           216
# PRESSÃO ATMOSFERICA MIN. NA HORA ANT. (AUT) (mB)          216
# RADIACAO GLOBAL (Kj/m²)                                  4171
# TEMPERATURA DO AR - BULBO SECO, HORARIA (°C)              212
# TEMPERATURA DO PONTO DE ORVALHO (°C)                      212
# TEMPERATURA MÁXIMA NA HORA ANT. (AUT) (°C)                216
# TEMPERATURA MÍNIMA NA HORA ANT. (AUT) (°C)                216
# TEMPERATURA ORVALHO MAX. NA HORA ANT. (AUT) (°C)          216
# TEMPERATURA ORVALHO MIN. NA HORA ANT. (AUT) (°C)          216
# UMIDADE REL. MAX. NA HORA ANT. (AUT) (%)                  216
# UMIDADE REL. MIN. NA HORA ANT. (AUT) (%)                  216
# ...

# %%
df.dropna(subset=['RADIACAO GLOBAL (Kj/m²)'])
# Out:
#             Data  Hora UTC PRECIPITAÇÃO TOTAL, HORÁRIO (mm)  \
# 9     2023/01/01  0900 UTC                                0
# 10    2023/01/01  1000 UTC                                0
# 11    2023/01/01  1100 UTC                                0
# 12    2023/01/01  1200 UTC                                0
# 13    2023/01/01  1300 UTC                                0
# ...          ...       ...                              ...
# 8754  2023/12/31  1800 UTC                                0
# 8755  2023/12/31  1900 UTC                                0
# 8756  2023/12/31  2000 UTC                                0
# 8757  2023/12/31  2100 UTC                                0
# 8758  2023/12/31  2200 UTC                                0
#
#      PRESSAO ATMOSFERICA AO NIVEL DA ESTACAO, HORARIA (mB)  \
# 9                                                 926,3
# 10                                                  927
# 11                                                927,5
# ...

# %% [markdown]
# 3. Copiar o dataframe reduzindo para 3 colunas (a sua escolha) e 1000 linhas (aleatórias)

# %%
df_reduzido = df[['Data', 'PRECIPITAÇÃO TOTAL, HORÁRIO (mm)', 'TEMPERATURA DO PONTO DE ORVALHO (°C)']]
print (df_reduzido)
# Out:
#             Data PRECIPITAÇÃO TOTAL, HORÁRIO (mm)  \
# 0     2023/01/01                                0
# 1     2023/01/01                                0
# 2     2023/01/01                                0
# 3     2023/01/01                                0
# 4     2023/01/01                                0
# ...          ...                              ...
# 8755  2023/12/31                                0
# 8756  2023/12/31                                0
# 8757  2023/12/31                                0
# 8758  2023/12/31                                0
# 8759  2023/12/31                                0
#
#      TEMPERATURA DO PONTO DE ORVALHO (°C)
# 0                                    17,2
# 1                                    17,5
# 2                                    17,9
# 3                                    17,9
# 4                                    17,3
# ...                                   ...
# 8755                                 16,4
# ...

# %%
df_reduzido_1000 = df.head(1000)
print(df_reduzido_1000)
# Out:
#            Data  Hora UTC PRECIPITAÇÃO TOTAL, HORÁRIO (mm)  \
# 0    2023/01/01  0000 UTC                                0
# 1    2023/01/01  0100 UTC                                0
# 2    2023/01/01  0200 UTC                                0
# 3    2023/01/01  0300 UTC                                0
# 4    2023/01/01  0400 UTC                                0
# ..          ...       ...                              ...
# 995  2023/02/11  1100 UTC                               ,2
# 996  2023/02/11  1200 UTC                                0
# 997  2023/02/11  1300 UTC                                0
# 998  2023/02/11  1400 UTC                                0
# 999  2023/02/11  1500 UTC                                0
#
#     PRESSAO ATMOSFERICA AO NIVEL DA ESTACAO, HORARIA (mB)  \
# 0                                                927,2
# 1                                                927,2
# 2                                                927,1
# ...
