# %% [markdown]
# ## Dados utilizados da cidade do Rio de Janeiro do Forte de Copacabana no ano 2023

# %%
import pandas as pd

df = pd.read_csv('RIO-DE-JANEIRO_FORTE-DE-COPACABANA_2023.csv', delimiter=';', skiprows=8, encoding='latin1')

# %%
df.columns
# Out:
# Index(['Data', 'Hora UTC', 'PRECIPITAÇÃO TOTAL, HORÁRIO (mm)',
#        'PRESSAO ATMOSFERICA AO NIVEL DA ESTACAO, HORARIA (mB)',
#        'PRESSÃO ATMOSFERICA MAX.NA HORA ANT. (AUT) (mB)',
#        'PRESSÃO ATMOSFERICA MIN. NA HORA ANT. (AUT) (mB)',
#        'RADIACAO GLOBAL (Kj/m²)',
#        'TEMPERATURA DO AR - BULBO SECO, HORARIA (°C)',
#        'TEMPERATURA DO PONTO DE ORVALHO (°C)',
#        'TEMPERATURA MÁXIMA NA HORA ANT. (AUT) (°C)',
#        'TEMPERATURA MÍNIMA NA HORA ANT. (AUT) (°C)',
#        'TEMPERATURA ORVALHO MAX. NA HORA ANT. (AUT) (°C)',
#        'TEMPERATURA ORVALHO MIN. NA HORA ANT. (AUT) (°C)',
#        'UMIDADE REL. MAX. NA HORA ANT. (AUT) (%)',
#        'UMIDADE REL. MIN. NA HORA ANT. (AUT) (%)',
#        'UMIDADE RELATIVA DO AR, HORARIA (%)',
#        'VENTO, DIREÇÃO HORARIA (gr) (° (gr))', 'VENTO, RAJADA MAXIMA (m/s)',
#        'VENTO, VELOCIDADE HORARIA (m/s)', 'Unnamed: 19'],
#       dtype='object')

# %% [markdown]
# **1. Calcular a média da temperatura da amostra**

# %%
print(df['TEMPERATURA DO AR - BULBO SECO, HORARIA (°C)'].dtype)
# Out:
# object

# %%
df['TEMPERATURA DO AR - BULBO SECO, HORARIA (°C)'] = pd.to_numeric(df['TEMPERATURA DO AR - BULBO SECO, HORARIA (°C)'], errors='coerce')

media = df['TEMPERATURA DO AR - BULBO SECO, HORARIA (°C)'].mean()
print(f"A média da temperatura é de {media:.2f}°C.")
# Out:
# A média da temperatura é de 24.15°C.

# %% [markdown]
# **2. Retirar nulos da coluna 'RADIACAO GLOBAL (Kj/m²)'**

# %%
df_sem_nulos_coluna = df.dropna(subset=['RADIACAO GLOBAL (Kj/m²)'])
df_sem_nulos_coluna
# Out:
#             Data  Hora UTC PRECIPITAÇÃO TOTAL, HORÁRIO (mm)  \
# 9     2023/01/01  0900 UTC                                0
# 10    2023/01/01  1000 UTC                                0
# 11    2023/01/01  1100 UTC                                0
# 12    2023/01/01  1200 UTC                                0
# 13    2023/01/01  1300 UTC                                0
# ...          ...       ...                              ...
# 8754  2023/12/31  1800 UTC                                0
# 8755  2023/12/31  1900 UTC                                0
# 8756  2023/12/31  2000 UTC                               ,2
# 8757  2023/12/31  2100 UTC                                0
# 8758  2023/12/31  2200 UTC                                0
#
#      PRESSAO ATMOSFERICA AO NIVEL DA ESTACAO, HORARIA (mB)  \
# 9                                                1010,2
# 10                                               1010,9
# 11                                               1011,1
# 12                                               1011,6
# 13                                               1011,5
# ...                                                 ...
# 8754                                             1011,6
# 8755                                               1011
# 8756                                             1010,8
# 8757                                               1011
# 8758                                             1011,7
#
#      PRESSÃO ATMOSFERICA MAX.NA HORA ANT. (AUT) (mB)  \
# 9                                             1010,2
# 10                                            1010,9
# 11                                            1011,2
# 12                                            1011,6
# 13                                            1011,6
# ...                                              ...
# 8754                                            1012
# 8755                                          1011,6
# 8756                                          1011,1
# 8757                                            1011
# 8758                                          1011,7
#
#      PRESSÃO ATMOSFERICA MIN. NA HORA ANT. (AUT) (mB) RADIACAO GLOBAL (Kj/m²)  \
# 9                                              1009,2                   124,6
# 10                                             1010,2                   887,1
# 11                                             1010,9                  1533,7
# 12                                             1011,1                  1983,3
# 13                                             1011,5                  3094,8
# ...                                               ...                     ...
# 8754                                           1011,6                  1133,5
# 8755                                             1011                     749
# 8756                                           1010,7                   470,2
# 8757                                           1010,8                   142,1
# 8758                                             1011                    20,7
#
#       TEMPERATURA DO AR - BULBO SECO, HORARIA (°C)  \
# 9                                             23.0
# 10                                            24.0
# 11                                             NaN
# 12                                             NaN
# 13                                             NaN
# ...                                            ...
# 8754                                           NaN
# 8755                                           NaN
# 8756                                           NaN
# 8757                                           NaN
# 8758                                           NaN
#
#      TEMPERATURA DO PONTO DE ORVALHO (°C)  \
# 9                                     NaN
# 10                                    NaN
# 11                                   26,2
# 12                                   20,5
# 13                                   21,1
# ...                                   ...
# 8754                                 20,8
# 8755                                 21,1
# 8756                                 20,7
# 8757                                 20,9
# 8758                                 21,3
#
#      TEMPERATURA MÁXIMA NA HORA ANT. (AUT) (°C)  \
# 9                                          23,2
# 10                                         24,2
# 11                                         26,3
# 12                                         26,5
# 13                                         27,8
# ...                                         ...
# 8754                                       25,7
# 8755                                       25,1
# 8756                                       24,6
# 8757                                       23,8
# 8758                                       23,3
#
#      TEMPERATURA MÍNIMA NA HORA ANT. (AUT) (°C)  \
# 9                                          22,7
# 10                                         22,9
# 11                                         23,7
# 12                                         24,2
# 13                                         24,2
# ...                                         ...
# 8754                                       24,6
# 8755                                       24,4
# 8756                                       23,8
# 8757                                       23,3
# 8758                                         23
#
#      TEMPERATURA ORVALHO MAX. NA HORA ANT. (AUT) (°C)  \
# 9                                                 NaN
# 10                                                NaN
# 11                                                NaN
# 12                                                 26
# 13                                               22,7
# ...                                               ...
# 8754                                             21,6
# 8755                                             21,3
# 8756                                             21,4
# 8757                                             21,1
# 8758                                             21,3
#
#      TEMPERATURA ORVALHO MIN. NA HORA ANT. (AUT) (°C)  \
# 9                                                 NaN
# 10                                                NaN
# 11                                                NaN
# 12                                                 20
# 13                                               20,2
# ...                                               ...
# 8754                                             20,6
# 8755                                             20,6
# 8756                                             20,5
# 8757                                             20,6
# 8758                                             20,7
#
#       UMIDADE REL. MAX. NA HORA ANT. (AUT) (%)  \
# 9                                          NaN
# 10                                         NaN
# 11                                         NaN
# 12                                        99.0
# 13                                        79.0
# ...                                        ...
# 8754                                      83.0
# 8755                                      82.0
# 8756                                      83.0
# 8757                                      87.0
# 8758                                      90.0
#
#       UMIDADE REL. MIN. NA HORA ANT. (AUT) (%)  \
# 9                                          NaN
# 10                                         NaN
# 11                                         NaN
# 12                                        77.0
# 13                                        68.0
# ...                                        ...
# 8754                                      75.0
# 8755                                      78.0
# 8756                                      81.0
# 8757                                      82.0
# 8758                                      86.0
#
#       UMIDADE RELATIVA DO AR, HORARIA (%)  \
# 9                                     NaN
# 10                                    NaN
# 11                                   99.0
# 12                                   79.0
# 13                                   68.0
# ...                                   ...
# 8754                                 79.0
# 8755                                 82.0
# 8756                                 83.0
# 8757                                 86.0
# 8758                                 90.0
#
#       VENTO, DIREÇÃO HORARIA (gr) (° (gr)) VENTO, RAJADA MAXIMA (m/s)  \
# 9                                    266.0                        3,3
# 10                                   226.0                        2,5
# 11                                   100.0                        1,9
# 12                                   254.0                          3
# 13                                   161.0                          3
# ...                                    ...                        ...
# 8754                                  88.0                        3,2
# 8755                                  63.0                        3,5
# 8756                                  95.0                        6,3
# 8757                                 100.0                        6,5
# 8758                                  82.0                        6,7
#
#      VENTO, VELOCIDADE HORARIA (m/s)  Unnamed: 19
# 9                                  1          NaN
# 10                               1,1          NaN
# 11                                ,9          NaN
# 12                               1,7          NaN
# 13                               1,5          NaN
# ...                              ...          ...
# 8754                             1,3          NaN
# 8755                             1,3          NaN
# 8756                             4,5          NaN
# 8757                             5,1          NaN
# 8758                             4,1          NaN
#
# [4736 rows x 20 columns]

# %% [markdown]
# **3. Copiar o dataframe reduzindo para 3 colunas e 1000 linhas aleatórias**

# %%
# Selecionar colunas específicas
df_reduzido = df[['Data', 'UMIDADE RELATIVA DO AR, HORARIA (%)', 'VENTO, VELOCIDADE HORARIA (m/s)']]

df_reduzido.head()
# Out:
#          Data  UMIDADE RELATIVA DO AR, HORARIA (%)  \
# 0  2023/01/01                                 67.0
# 1  2023/01/01                                 80.0
# 2  2023/01/01                                  NaN
# 3  2023/01/01                                  NaN
# 4  2023/01/01                                  NaN
#
#   VENTO, VELOCIDADE HORARIA (m/s)
# 0                               2
# 1                               1
# 2                             1,3
# 3                             1,4
# 4                              ,6

# %%
# Selecionar 1000 linhas aleatórias
df_reduzido = df_reduzido.sample(n=1000, random_state=42)

df_reduzido
# Out:
#             Data  UMIDADE RELATIVA DO AR, HORARIA (%)  \
# 8046  2023/12/02                                  NaN
# 3910  2023/06/12                                  NaN
# 411   2023/01/18                                 78.0
# 3146  2023/05/12                                 70.0
# 8664  2023/12/28                                 82.0
# ...          ...                                  ...
# 6152  2023/09/14                                 37.0
# 7550  2023/11/11                                  NaN
# 8476  2023/12/20                                 96.0
# 828   2023/02/04                                 67.0
# 6266  2023/09/19                                  NaN
#
#      VENTO, VELOCIDADE HORARIA (m/s)
# 8046                              ,7
# 3910                               3
# 411                              1,2
# 3146                             1,1
# 8664                             1,3
# ...                              ...
# 6152                             4,8
# 7550                             4,6
# 8476                              ,8
# 828                              1,6
# 6266                             1,7
#
# [1000 rows x 3 columns]

# %% [markdown]
# #### **Bônus I: Normalizar uma coluna**
#
# #### Coluna usada: 'UMIDADE RELATIVA DO AR, HORARIA (%)'

# %%
df['Coluna_normalizada'] = (df['UMIDADE RELATIVA DO AR, HORARIA (%)'] - df['UMIDADE RELATIVA DO AR, HORARIA (%)'].min()) / (df['UMIDADE RELATIVA DO AR, HORARIA (%)'].max() - df['UMIDADE RELATIVA DO AR, HORARIA (%)'].min())
df['Coluna_normalizada']
# Out:
# 0       0.625000
# 1       0.772727
# 2            NaN
# 3            NaN
# 4            NaN
#           ...
# 8755    0.795455
# 8756    0.806818
# 8757    0.840909
# 8758    0.886364
# 8759    0.829545
# Name: Coluna_normalizada, Length: 8760, dtype: float64

# %% [markdown]
# #### **Bônus II: Outra forma de processamento de dados**
#
# #### Filtrar linhas com base em condições:
#
# Coluna usada: 'VENTO, VELOCIDADE HORARIA (m/s)'

# %%
df['VENTO, VELOCIDADE HORARIA (m/s)'] = pd.to_numeric(df['VENTO, VELOCIDADE HORARIA (m/s)'], errors='coerce')

filtrado = df[df['VENTO, VELOCIDADE HORARIA (m/s)'] > 2]
filtrado
# Out:
#             Data  Hora UTC PRECIPITAÇÃO TOTAL, HORÁRIO (mm)  \
# 39    2023/01/02  1500 UTC                                0
# 81    2023/01/04  0900 UTC                                0
# 96    2023/01/05  0000 UTC                                0
# 101   2023/01/05  0500 UTC                                0
# 115   2023/01/05  1900 UTC                                0
# ...          ...       ...                              ...
# 8657  2023/12/27  1700 UTC                                0
# 8659  2023/12/27  1900 UTC                                0
# 8685  2023/12/28  2100 UTC                                0
# 8728  2023/12/30  1600 UTC                                0
# 8733  2023/12/30  2100 UTC                                0
#
#      PRESSAO ATMOSFERICA AO NIVEL DA ESTACAO, HORARIA (mB)  \
# 39                                               1007,9
# 81                                               1002,5
# 96                                               1005,9
# 101                                              1004,8
# 115                                              1006,3
# ...                                                 ...
# 8657                                             1012,3
# 8659                                             1011,8
# 8685                                             1008,1
# 8728                                             1009,4
# 8733                                             1010,4
#
#      PRESSÃO ATMOSFERICA MAX.NA HORA ANT. (AUT) (mB)  \
# 39                                            1008,9
# 81                                            1002,5
# 96                                            1005,9
# 101                                           1005,3
# 115                                           1006,7
# ...                                              ...
# 8657                                          1012,8
# 8659                                          1012,1
# 8685                                          1008,4
# 8728                                          1009,4
# 8733                                          1010,4
#
#      PRESSÃO ATMOSFERICA MIN. NA HORA ANT. (AUT) (mB) RADIACAO GLOBAL (Kj/m²)  \
# 39                                             1007,9                  3957,9
# 81                                             1002,3                    54,1
# 96                                             1005,8                     NaN
# 101                                            1004,7                     NaN
# 115                                            1006,2                   282,9
# ...                                               ...                     ...
# 8657                                           1012,3                  3032,5
# 8659                                           1011,8                  2361,8
# 8685                                             1008                   175,8
# 8728                                           1008,8                  1026,5
# 8733                                           1009,8                   112,9
#
#       TEMPERATURA DO AR - BULBO SECO, HORARIA (°C)  \
# 39                                             NaN
# 81                                             NaN
# 96                                             NaN
# 101                                            NaN
# 115                                            NaN
# ...                                            ...
# 8657                                           NaN
# 8659                                           NaN
# 8685                                           NaN
# 8728                                           NaN
# 8733                                           NaN
#
#      TEMPERATURA DO PONTO DE ORVALHO (°C)  \
# 39                                   20,1
# 81                                   16,9
# 96                                    NaN
# 101                                   NaN
# 115                                   NaN
# ...                                   ...
# 8657                                 21,3
# 8659                                 21,9
# 8685                                 21,8
# 8728                                 23,7
# 8733                                 21,7
#
#      TEMPERATURA MÁXIMA NA HORA ANT. (AUT) (°C)  ...  \
# 39                                         28,7  ...
# 81                                         29,5  ...
# 96                                         23,5  ...
# 101                                        22,4  ...
# 115                                          22  ...
# ...                                         ...  ...
# 8657                                       28,4  ...
# 8659                                       27,3  ...
# 8685                                       25,1  ...
# 8728                                       26,2  ...
# 8733                                       23,9  ...
#
#      TEMPERATURA ORVALHO MAX. NA HORA ANT. (AUT) (°C)  \
# 39                                                 21
# 81                                               17,5
# 96                                                NaN
# 101                                               NaN
# 115                                               NaN
# ...                                               ...
# 8657                                             22,6
# 8659                                             22,4
# 8685                                             21,8
# 8728                                             23,9
# 8733                                             22,3
#
#      TEMPERATURA ORVALHO MIN. NA HORA ANT. (AUT) (°C)  \
# 39                                               19,5
# 81                                               16,9
# 96                                                NaN
# 101                                               NaN
# 115                                               NaN
# ...                                               ...
# 8657                                             21,2
# 8659                                             21,6
# 8685                                             21,4
# 8728                                             23,2
# 8733                                             21,7
#
#      UMIDADE REL. MAX. NA HORA ANT. (AUT) (%)  \
# 39                                       65.0
# 81                                       54.0
# 96                                        NaN
# 101                                       NaN
# 115                                       NaN
# ...                                       ...
# 8657                                     77.0
# 8659                                     78.0
# 8685                                     85.0
# 8728                                     92.0
# 8733                                     92.0
#
#       UMIDADE REL. MIN. NA HORA ANT. (AUT) (%)  \
# 39                                        60.0
# 81                                        47.0
# 96                                         NaN
# 101                                        NaN
# 115                                        NaN
# ...                                        ...
# 8657                                      69.0
# 8659                                      73.0
# 8685                                      81.0
# 8728                                      84.0
# 8733                                      89.0
#
#       UMIDADE RELATIVA DO AR, HORARIA (%)  \
# 39                                   62.0
# 81                                   47.0
# 96                                    NaN
# 101                                   NaN
# 115                                   NaN
# ...                                   ...
# 8657                                 76.0
# 8659                                 77.0
# 8685                                 85.0
# 8728                                 92.0
# 8733                                 91.0
#
#       VENTO, DIREÇÃO HORARIA (gr) (° (gr))  VENTO, RAJADA MAXIMA (m/s)  \
# 39                                    76.0                         5,2
# 81                                   335.0                         8,7
# 96                                   267.0                         6,7
# 101                                  263.0                           7
# 115                                  266.0                        10,9
# ...                                    ...                         ...
# 8657                                 251.0                         6,3
# 8659                                 245.0                         6,7
# 8685                                  95.0                         9,8
# 8728                                 262.0                         8,5
# 8733                                 262.0                         7,8
#
#      VENTO, VELOCIDADE HORARIA (m/s)  Unnamed: 19  Coluna_normalizada
# 39                               3.0          NaN            0.568182
# 81                               3.0          NaN            0.397727
# 96                               3.0          NaN                 NaN
# 101                              3.0          NaN                 NaN
# 115                              4.0          NaN                 NaN
# ...                              ...          ...                 ...
# 8657                             3.0          NaN            0.727273
# 8659                             3.0          NaN            0.738636
# 8685                             7.0          NaN            0.829545
# 8728                             4.0          NaN            0.909091
# 8733                             3.0          NaN            0.897727
#
# [283 rows x 21 columns]
