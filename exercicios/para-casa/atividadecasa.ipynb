# %%
import pandas as pd

df = pd.read_csv('saopaulo.CSV', delimiter=';', skiprows=8, encoding='latin1')

# %%
df_saopaulo = df.sample(n=20)

# %%
df_saopaulo.head()
# Out:
#             Data  Hora UTC PRECIPITAÇÃO TOTAL, HORÁRIO (mm)  \
# 2623  2020/04/19  0700 UTC                                0
# 3096  2020/05/09  0000 UTC                                0
# 2186  2020/04/01  0200 UTC                                0
# 4637  2020/07/12  0500 UTC                                0
# 321   2020/01/14  0900 UTC                                0
#
#      PRESSAO ATMOSFERICA AO NIVEL DA ESTACAO, HORARIA (mB)  \
# 2623                                              932,7
# 3096                                                935
# 2186                                              928,4
# 4637                                              927,6
# 321                                               928,4
#
#      PRESSÃO ATMOSFERICA MAX.NA HORA ANT. (AUT) (mB)  \
# 2623                                           932,9
# 3096                                             935
# 2186                                           928,5
# 4637                                           928,1
# 321                                            928,4
#
#      PRESSÃO ATMOSFERICA MIN. NA HORA ANT. (AUT) (mB) RADIACAO GLOBAL (Kj/m²)  \
# 2623                                            932,7                     NaN
# 3096                                            934,8                     NaN
# 2186                                            928,3                     NaN
# 4637                                            927,6                     NaN
# 321                                               928                    11,9
#
#      TEMPERATURA DO AR - BULBO SECO, HORARIA (°C)  \
# 2623                                           16
# 3096                                         14,6
# 2186                                         18,4
# 4637                                         16,2
# 321                                          18,8
#
#      TEMPERATURA DO PONTO DE ORVALHO (°C)  \
# 2623                                 14,6
# 3096                                   13
# 2186                                 17,5
# 4637                                 12,8
# 321                                    17
#
#      TEMPERATURA MÁXIMA NA HORA ANT. (AUT) (°C)  \
# 2623                                         16
# 3096                                       14,7
# 2186                                       18,5
# 4637                                       17,4
# 321                                        18,9
#
#      TEMPERATURA MÍNIMA NA HORA ANT. (AUT) (°C)  \
# 2623                                       15,8
# 3096                                       14,3
# 2186                                       18,2
# 4637                                       16,2
# 321                                        18,7
#
#      TEMPERATURA ORVALHO MAX. NA HORA ANT. (AUT) (°C)  \
# 2623                                             14,7
# 3096                                               13
# 2186                                             17,6
# 4637                                               13
# 321                                              17,1
#
#      TEMPERATURA ORVALHO MIN. NA HORA ANT. (AUT) (°C)  \
# 2623                                             14,4
# 3096                                               12
# 2186                                             17,3
# 4637                                             12,7
# 321                                              16,6
#
#       UMIDADE REL. MAX. NA HORA ANT. (AUT) (%)  \
# 2623                                      92.0
# 3096                                      90.0
# 2186                                      95.0
# 4637                                      80.0
# 321                                       90.0
#
#       UMIDADE REL. MIN. NA HORA ANT. (AUT) (%)  \
# 2623                                      91.0
# 3096                                      86.0
# 2186                                      94.0
# 4637                                      75.0
# 321                                       87.0
#
#       UMIDADE RELATIVA DO AR, HORARIA (%)  \
# 2623                                 92.0
# 3096                                 90.0
# 2186                                 95.0
# 4637                                 80.0
# 321                                  89.0
#
#       VENTO, DIREÇÃO HORARIA (gr) (° (gr)) VENTO, RAJADA MAXIMA (m/s)  \
# 2623                                 113.0                        3,7
# 3096                                 121.0                        5,9
# 2186                                 127.0                        2,6
# 4637                                 310.0                        1,5
# 321                                  111.0                        5,6
#
#      VENTO, VELOCIDADE HORARIA (m/s)  Unnamed: 19
# 2623                             1,1          NaN
# 3096                             2,3          NaN
# 2186                              ,8          NaN
# 4637                              ,9          NaN
# 321                              2,1          NaN

# %%
coluna_temperatura_maxima = df['TEMPERATURA MÁXIMA NA HORA ANT. (AUT) (°C)']

# %%
coluna_temperatura_maxima = pd.to_numeric(df['TEMPERATURA MÁXIMA NA HORA ANT. (AUT) (°C)'], errors='coerce')

# %%
coluna_temperatura_maxima.mean()
# Out:
# np.float64(20.114754098360656)

# %%
coluna_radiacao_global = df['RADIACAO GLOBAL (Kj/m²)']

# %%
coluna_radiacao_global.head()
# Out:
# 0    NaN
# 1    NaN
# 2    NaN
# 3    NaN
# 4    NaN
# Name: RADIACAO GLOBAL (Kj/m²), dtype: object

# %%
df.isnull()
# Out:
#        Data  Hora UTC  PRECIPITAÇÃO TOTAL, HORÁRIO (mm)  \
# 0     False     False                             False
# 1     False     False                             False
# 2     False     False                             False
# 3     False     False                             False
# 4     False     False                             False
# ...     ...       ...                               ...
# 8779  False     False                             False
# 8780  False     False                             False
# 8781  False     False                             False
# 8782  False     False                             False
# 8783  False     False                             False
#
#       PRESSAO ATMOSFERICA AO NIVEL DA ESTACAO, HORARIA (mB)  \
# 0                                                 False
# 1                                                 False
# 2                                                 False
# 3                                                 False
# 4                                                 False
# ...                                                 ...
# 8779                                              False
# 8780                                              False
# 8781                                              False
# 8782                                              False
# 8783                                              False
#
#       PRESSÃO ATMOSFERICA MAX.NA HORA ANT. (AUT) (mB)  \
# 0                                               False
# 1                                               False
# 2                                               False
# 3                                               False
# 4                                               False
# ...                                               ...
# 8779                                            False
# 8780                                            False
# 8781                                            False
# 8782                                            False
# 8783                                            False
#
#       PRESSÃO ATMOSFERICA MIN. NA HORA ANT. (AUT) (mB)  \
# 0                                                False
# 1                                                False
# 2                                                False
# 3                                                False
# 4                                                False
# ...                                                ...
# 8779                                             False
# 8780                                             False
# 8781                                             False
# 8782                                             False
# 8783                                             False
#
#       RADIACAO GLOBAL (Kj/m²)  TEMPERATURA DO AR - BULBO SECO, HORARIA (°C)  \
# 0                        True                                         False
# 1                        True                                         False
# 2                        True                                         False
# 3                        True                                         False
# 4                        True                                         False
# ...                       ...                                           ...
# 8779                    False                                         False
# 8780                    False                                         False
# 8781                    False                                         False
# 8782                    False                                         False
# 8783                     True                                         False
#
#       TEMPERATURA DO PONTO DE ORVALHO (°C)  \
# 0                                    False
# 1                                    False
# 2                                    False
# 3                                    False
# 4                                    False
# ...                                    ...
# 8779                                 False
# 8780                                 False
# 8781                                 False
# 8782                                 False
# 8783                                 False
#
#       TEMPERATURA MÁXIMA NA HORA ANT. (AUT) (°C)  \
# 0                                          False
# 1                                          False
# 2                                          False
# 3                                          False
# 4                                          False
# ...                                          ...
# 8779                                       False
# 8780                                       False
# 8781                                       False
# 8782                                       False
# 8783                                       False
#
#       TEMPERATURA MÍNIMA NA HORA ANT. (AUT) (°C)  \
# 0                                          False
# 1                                          False
# 2                                          False
# 3                                          False
# 4                                          False
# ...                                          ...
# 8779                                       False
# 8780                                       False
# 8781                                       False
# 8782                                       False
# 8783                                       False
#
#       TEMPERATURA ORVALHO MAX. NA HORA ANT. (AUT) (°C)  \
# 0                                                False
# 1                                                False
# 2                                                False
# 3                                                False
# 4                                                False
# ...                                                ...
# 8779                                             False
# 8780                                             False
# 8781                                             False
# 8782                                             False
# 8783                                             False
#
#       TEMPERATURA ORVALHO MIN. NA HORA ANT. (AUT) (°C)  \
# 0                                                False
# 1                                                False
# 2                                                False
# 3                                                False
# 4                                                False
# ...                                                ...
# 8779                                             False
# 8780                                             False
# 8781                                             False
# 8782                                             False
# 8783                                             False
#
#       UMIDADE REL. MAX. NA HORA ANT. (AUT) (%)  \
# 0                                        False
# 1                                        False
# 2                                        False
# 3                                        False
# 4                                        False
# ...                                        ...
# 8779                                     False
# 8780                                     False
# 8781                                     False
# 8782                                     False
# 8783                                     False
#
#       UMIDADE REL. MIN. NA HORA ANT. (AUT) (%)  \
# 0                                        False
# 1                                        False
# 2                                        False
# 3                                        False
# 4                                        False
# ...                                        ...
# 8779                                     False
# 8780                                     False
# 8781                                     False
# 8782                                     False
# 8783                                     False
#
#       UMIDADE RELATIVA DO AR, HORARIA (%)  \
# 0                                   False
# 1                                   False
# 2                                   False
# 3                                   False
# 4                                   False
# ...                                   ...
# 8779                                False
# 8780                                False
# 8781                                False
# 8782                                False
# 8783                                False
#
#       VENTO, DIREÇÃO HORARIA (gr) (° (gr))  VENTO, RAJADA MAXIMA (m/s)  \
# 0                                    False                       False
# 1                                    False                       False
# 2                                    False                       False
# 3                                    False                       False
# 4                                    False                       False
# ...                                    ...                         ...
# 8779                                 False                       False
# 8780                                 False                       False
# 8781                                 False                       False
# 8782                                 False                       False
# 8783                                 False                       False
#
#       VENTO, VELOCIDADE HORARIA (m/s)  Unnamed: 19
# 0                               False         True
# 1                               False         True
# 2                               False         True
# 3                               False         True
# 4                               False         True
# ...                               ...          ...
# 8779                            False         True
# 8780                            False         True
# 8781                            False         True
# 8782                            False         True
# 8783                            False         True
#
# [8784 rows x 20 columns]

# %%
df.dropna()
# Out:
# Empty DataFrame
# Columns: [Data, Hora UTC, PRECIPITAÇÃO TOTAL, HORÁRIO (mm), PRESSAO ATMOSFERICA AO NIVEL DA ESTACAO, HORARIA (mB), PRESSÃO ATMOSFERICA MAX.NA HORA ANT. (AUT) (mB), PRESSÃO ATMOSFERICA MIN. NA HORA ANT. (AUT) (mB), RADIACAO GLOBAL (Kj/m²), TEMPERATURA DO AR - BULBO SECO, HORARIA (°C), TEMPERATURA DO PONTO DE ORVALHO (°C), TEMPERATURA MÁXIMA NA HORA ANT. (AUT) (°C), TEMPERATURA MÍNIMA NA HORA ANT. (AUT) (°C), TEMPERATURA ORVALHO MAX. NA HORA ANT. (AUT) (°C), TEMPERATURA ORVALHO MIN. NA HORA ANT. (AUT) (°C), UMIDADE REL. MAX. NA HORA ANT. (AUT) (%), UMIDADE REL. MIN. NA HORA ANT. (AUT) (%), UMIDADE RELATIVA DO AR, HORARIA (%), VENTO, DIREÇÃO HORARIA (gr) (° (gr)), VENTO, RAJADA MAXIMA (m/s), VENTO, VELOCIDADE HORARIA (m/s), Unnamed: 19]
# Index: []

# %%
df_reduzido  = df[['Data', 'PRECIPITAÇÃO TOTAL, HORÁRIO (mm)']]

# %%
df_reduzido.head(1000)
# Out:
#            Data PRECIPITAÇÃO TOTAL, HORÁRIO (mm)
# 0    2020/01/01                                0
# 1    2020/01/01                                0
# 2    2020/01/01                                0
# 3    2020/01/01                                0
# 4    2020/01/01                                0
# ..          ...                              ...
# 995  2020/02/11                               ,2
# 996  2020/02/11                               ,2
# 997  2020/02/11                                0
# 998  2020/02/11                                0
# 999  2020/02/11                                0
#
# [1000 rows x 2 columns]

# %%
df_substituido = df.replace('0','20')

# %%
df_substituido.head(10)
# Out:
#          Data  Hora UTC PRECIPITAÇÃO TOTAL, HORÁRIO (mm)  \
# 0  2020/01/01  0000 UTC                               20
# 1  2020/01/01  0100 UTC                               20
# 2  2020/01/01  0200 UTC                               20
# 3  2020/01/01  0300 UTC                               20
# 4  2020/01/01  0400 UTC                               20
# 5  2020/01/01  0500 UTC                               20
# 6  2020/01/01  0600 UTC                               20
# 7  2020/01/01  0700 UTC                               20
# 8  2020/01/01  0800 UTC                               20
# 9  2020/01/01  0900 UTC                               20
#
#   PRESSAO ATMOSFERICA AO NIVEL DA ESTACAO, HORARIA (mB)  \
# 0                                              923,1
# 1                                              923,7
# 2                                              923,6
# 3                                              923,1
# 4                                              922,6
# 5                                                922
# 6                                              921,8
# 7                                              921,7
# 8                                              922,1
# 9                                              922,3
#
#   PRESSÃO ATMOSFERICA MAX.NA HORA ANT. (AUT) (mB)  \
# 0                                           923,1
# 1                                           923,7
# 2                                           923,8
# 3                                           923,6
# 4                                           923,1
# 5                                           922,6
# 6                                             922
# 7                                           921,8
# 8                                           922,1
# 9                                           922,3
#
#   PRESSÃO ATMOSFERICA MIN. NA HORA ANT. (AUT) (mB) RADIACAO GLOBAL (Kj/m²)  \
# 0                                            922,1                     NaN
# 1                                            923,1                     NaN
# 2                                            923,6                     NaN
# 3                                            923,1                     NaN
# 4                                            922,6                     NaN
# 5                                              922                     NaN
# 6                                            921,8                     NaN
# 7                                            921,7                     NaN
# 8                                            921,7                     NaN
# 9                                            922,1                    42,4
#
#   TEMPERATURA DO AR - BULBO SECO, HORARIA (°C)  \
# 0                                           22
# 1                                         22,1
# 2                                         23,2
# 3                                         23,3
# 4                                         22,9
# 5                                         22,8
# 6                                         22,4
# 7                                         21,5
# 8                                         20,9
# 9                                         21,4
#
#   TEMPERATURA DO PONTO DE ORVALHO (°C)  \
# 0                                 20,5
# 1                                 20,7
# 2                                 20,1
# 3                                 19,5
# 4                                   19
# 5                                 19,2
# 6                                 18,7
# 7                                 18,3
# 8                                 18,5
# 9                                 18,9
#
#   TEMPERATURA MÁXIMA NA HORA ANT. (AUT) (°C)  \
# 0                                       22,2
# 1                                       22,3
# 2                                       23,5
# 3                                       23,6
# 4                                       23,6
# 5                                         23
# 6                                       22,9
# 7                                       22,5
# 8                                       21,6
# 9                                       21,4
#
#   TEMPERATURA MÍNIMA NA HORA ANT. (AUT) (°C)  \
# 0                                       21,8
# 1                                         22
# 2                                       22,1
# 3                                       23,1
# 4                                       22,8
# 5                                       22,6
# 6                                       22,2
# 7                                       21,4
# 8                                       20,9
# 9                                       20,6
#
#   TEMPERATURA ORVALHO MAX. NA HORA ANT. (AUT) (°C)  \
# 0                                             20,5
# 1                                             20,8
# 2                                             20,8
# 3                                             20,1
# 4                                             19,5
# 5                                             19,3
# 6                                             19,2
# 7                                             18,7
# 8                                             18,5
# 9                                             18,9
#
#   TEMPERATURA ORVALHO MIN. NA HORA ANT. (AUT) (°C)  \
# 0                                             20,3
# 1                                             20,4
# 2                                             20,1
# 3                                             19,4
# 4                                               19
# 5                                               19
# 6                                             18,7
# 7                                             18,3
# 8                                             18,3
# 9                                             18,5
#
#    UMIDADE REL. MAX. NA HORA ANT. (AUT) (%)  \
# 0                                      92.0
# 1                                      92.0
# 2                                      92.0
# 3                                      83.0
# 4                                      79.0
# 5                                      81.0
# 6                                      82.0
# 7                                      82.0
# 8                                      86.0
# 9                                      89.0
#
#    UMIDADE REL. MIN. NA HORA ANT. (AUT) (%)  \
# 0                                      90.0
# 1                                      90.0
# 2                                      82.0
# 3                                      78.0
# 4                                      76.0
# 5                                      79.0
# 6                                      79.0
# 7                                      79.0
# 8                                      82.0
# 9                                      86.0
#
#    UMIDADE RELATIVA DO AR, HORARIA (%)  VENTO, DIREÇÃO HORARIA (gr) (° (gr))  \
# 0                                 92.0                                 172.0
# 1                                 92.0                                 101.0
# 2                                 82.0                                   7.0
# 3                                 79.0                                   6.0
# 4                                 79.0                                 345.0
# 5                                 80.0                                  14.0
# 6                                 79.0                                 350.0
# 7                                 82.0                                 328.0
# 8                                 86.0                                 315.0
# 9                                 86.0                                 328.0
#
#   VENTO, RAJADA MAXIMA (m/s) VENTO, VELOCIDADE HORARIA (m/s)  Unnamed: 19
# 0                        2,8                              ,4          NaN
# 1                        1,8                              ,9          NaN
# 2                        3,3                             1,2          NaN
# 3                          3                             1,2          NaN
# 4                        3,5                              ,6          NaN
# 5                        4,4                             1,9          NaN
# 6                        4,4                             1,3          NaN
# 7                        3,3                             1,1          NaN
# 8                        2,4                              ,5          NaN
# 9                        2,5                             1,5          NaN
