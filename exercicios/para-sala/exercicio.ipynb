# %% [markdown]
# # Exercício de Sala

# %%
print("Olá mundo")
# Out:
# Olá mundo

# %%
import pandas as pd

df = pd.read_csv('RECIFE2020.CSV', delimiter=';', skiprows=8, encoding='latin1')

# %%
# Exibe as 5 primeiras linhas
df.head()
# Out:
#          Data  Hora UTC PRECIPITAÇÃO TOTAL, HORÁRIO (mm)  \
# 0  01/01/2020  0000 UTC                                0
# 1  01/01/2020  0100 UTC                                0
# 2  01/01/2020  0200 UTC                                0
# 3  01/01/2020  0300 UTC                                0
# 4  01/01/2020  0400 UTC                              0,8
#
#   PRESSAO ATMOSFERICA AO NIVEL DA ESTACAO, HORARIA (mB)  \
# 0                                             1011,8
# 1                                             1011,9
# 2                                             1011,8
# 3                                             1011,5
# 4                                             1010,6
#
#   PRESSÃO ATMOSFERICA MAX.NA HORA ANT. (AUT) (mB)  \
# 0                                          1011,9
# 1                                          1011,9
# 2                                            1012
# 3                                          1011,8
# ...

# %%
#Exibe as 20 primeiras linhas
df.head(20)
# Out:
#           Data  Hora UTC PRECIPITAÇÃO TOTAL, HORÁRIO (mm)  \
# 0   01/01/2020  0000 UTC                                0
# 1   01/01/2020  0100 UTC                                0
# 2   01/01/2020  0200 UTC                                0
# 3   01/01/2020  0300 UTC                                0
# 4   01/01/2020  0400 UTC                              0,8
# 5   01/01/2020  0500 UTC                                0
# 6   01/01/2020  0600 UTC                              0,2
# 7   01/01/2020  0700 UTC                                0
# 8   01/01/2020  0800 UTC                                0
# 9   01/01/2020  0900 UTC                                0
# 10  01/01/2020  1000 UTC                                0
# 11  01/01/2020  1100 UTC                                0
# 12  01/01/2020  1200 UTC                                0
# 13  01/01/2020  1300 UTC                                0
# 14  01/01/2020  1400 UTC                                0
# ...

# %%
#Exibe as 5 últimas linhas
df.tail()
# Out:
#             Data  Hora UTC PRECIPITAÇÃO TOTAL, HORÁRIO (mm)  \
# 8779  31/12/2020  1900 UTC                                0
# 8780  31/12/2020  2000 UTC                                0
# 8781  31/12/2020  2100 UTC                                0
# 8782  31/12/2020  2200 UTC                                0
# 8783  31/12/2020  2300 UTC                                0
#
#      PRESSAO ATMOSFERICA AO NIVEL DA ESTACAO, HORARIA (mB)  \
# 8779                                             1011,3
# 8780                                             1011,6
# 8781                                             1012,1
# 8782                                             1012,5
# 8783                                             1012,9
#
#      PRESSÃO ATMOSFERICA MAX.NA HORA ANT. (AUT) (mB)  \
# 8779                                          1011,3
# 8780                                          1011,7
# 8781                                          1012,1
# ...

# %%
#Retorna a quantidade de linhas e colunas do DataFrame em formato de tupla
#Shape não usa parêntese porque é um atributo.
df.shape
# Out:
# (8784, 19)

# %%
#Estatística descritiva
df.describe()
# Out:
#        UMIDADE REL. MAX. NA HORA ANT. (AUT) (%)  \
# count                               8776.000000
# mean                                  78.467525
# std                                   11.411529
# min                                   44.000000
# 25%                                   69.000000
# 50%                                   79.000000
# 75%                                   90.000000
# max                                   94.000000
#
#        UMIDADE REL. MIN. NA HORA ANT. (AUT) (%)  \
# count                               8776.000000
# mean                                  73.986896
# std                                   13.368984
# min                                   39.000000
# 25%                                   63.000000
# 50%                                   74.000000
# 75%                                   87.000000
# max                                   94.000000
#
#        UMIDADE RELATIVA DO AR, HORARIA (%)  \
# ...

# %%
# Exibe os tipos de dados das colunas
df.dtypes
# Out:
# Data                                                      object
# Hora UTC                                                  object
# PRECIPITAÇÃO TOTAL, HORÁRIO (mm)                          object
# PRESSAO ATMOSFERICA AO NIVEL DA ESTACAO, HORARIA (mB)     object
# PRESSÃO ATMOSFERICA MAX.NA HORA ANT. (AUT) (mB)           object
# PRESSÃO ATMOSFERICA MIN. NA HORA ANT. (AUT) (mB)          object
# RADIACAO GLOBAL (Kj/m²)                                   object
# TEMPERATURA DO AR - BULBO SECO, HORARIA (°C)              object
# TEMPERATURA DO PONTO DE ORVALHO (°C)                      object
# TEMPERATURA MÁXIMA NA HORA ANT. (AUT) (°C)                object
# TEMPERATURA MÍNIMA NA HORA ANT. (AUT) (°C)                object
# TEMPERATURA ORVALHO MAX. NA HORA ANT. (AUT) (°C)          object
# TEMPERATURA ORVALHO MIN. NA HORA ANT. (AUT) (°C)          object
# UMIDADE REL. MAX. NA HORA ANT. (AUT) (%)                 float64
# ...

# %%
# Seleciona 5 linhas aleatórias
df.sample(n=5)
# Out:
#             Data  Hora UTC PRECIPITAÇÃO TOTAL, HORÁRIO (mm)  \
# 6423  24/09/2020  1500 UTC                                0
# 8108  03/12/2020  2000 UTC                                0
# 1646  09/03/2020  1400 UTC                                0
# 190   08/01/2020  2200 UTC                                0
# 4706  15/07/2020  0200 UTC                                0
#
#      PRESSAO ATMOSFERICA AO NIVEL DA ESTACAO, HORARIA (mB)  \
# 6423                                             1015,2
# 8108                                             1011,7
# 1646                                             1011,8
# 190                                              1011,2
# 4706                                             1015,4
#
#      PRESSÃO ATMOSFERICA MAX.NA HORA ANT. (AUT) (mB)  \
# 6423                                          1016,1
# 8108                                          1011,7
# 1646                                          1012,1
# ...

# %%
#Reduzir data frame
df_reduzido = df[['Data', 'Hora UTC', 'PRECIPITAÇÃO TOTAL, HORÁRIO (mm)']]

# %%
#Data frame reduzido
df_reduzido.head()
# Out:
#          Data  Hora UTC PRECIPITAÇÃO TOTAL, HORÁRIO (mm)
# 0  01/01/2020  0000 UTC                                0
# 1  01/01/2020  0100 UTC                                0
# 2  01/01/2020  0200 UTC                                0
# 3  01/01/2020  0300 UTC                                0
# 4  01/01/2020  0400 UTC                              0,8
