# %%
import pandas as pd

df = pd.read_csv('INMET_CO_DF_A001_BRASILIA_01-01-2023_A_31-12-2023.csv', delimiter=';', skiprows=8, encoding='latin1')

# %%
df.head()
# Out:
#          Data  Hora UTC PRECIPITAÇÃO TOTAL, HORÁRIO (mm)  \
# 0  2023/01/01  0000 UTC                                0
# 1  2023/01/01  0100 UTC                                0
# 2  2023/01/01  0200 UTC                                0
# 3  2023/01/01  0300 UTC                                0
# 4  2023/01/01  0400 UTC                                0
#
#   PRESSAO ATMOSFERICA AO NIVEL DA ESTACAO, HORARIA (mB)  \
# 0                                              887,7
# 1                                              888,1
# 2                                              887,8
# 3                                              887,8
# 4                                              887,6
#
#   PRESSÃO ATMOSFERICA MAX.NA HORA ANT. (AUT) (mB)  \
# 0                                           887,7
# 1                                           888,1
# 2                                           888,1
# 3                                           887,9
# ...

# %%
df_reduzido = df[['Data', 'TEMPERATURA MÍNIMA NA HORA ANT. (AUT) (°C)', 'TEMPERATURA MÁXIMA NA HORA ANT. (AUT) (°C)', 'TEMPERATURA ORVALHO MAX. NA HORA ANT. (AUT) (°C)', 'UMIDADE REL. MAX. NA HORA ANT. (AUT) (%)']]
df_reduzido.sample(20)
# Out:
#             Data TEMPERATURA MÍNIMA NA HORA ANT. (AUT) (°C)  \
# 4238  2023/06/26                                         19
# 1633  2023/03/10                                       21,4
# 8523  2023/12/22                                         19
# 346   2023/01/15                                       17,3
# 5566  2023/08/20                                       20,6
# 7666  2023/11/16                                       21,4
# 3070  2023/05/08                                         21
# 3858  2023/06/10                                       25,1
# 7686  2023/11/17                                         22
# 6288  2023/09/20                                       25,4
# 3815  2023/06/08                                       20,5
# 6791  2023/10/10                                       24,9
# 4108  2023/06/21                                       17,2
# 8001  2023/11/30                                       19,8
# 1894  2023/03/20                                       19,1
# ...

# %%
df_reduzido_temperatura = df_reduzido['TEMPERATURA MÁXIMA NA HORA ANT. (AUT) (°C)'].str.replace(',','.')
df_reduzido_temperatura.head()
# Out:
# 0    20.9
# 1    20.1
# 2    19.5
# 3    19.4
# 4    19.7
# Name: TEMPERATURA MÁXIMA NA HORA ANT. (AUT) (°C), dtype: object
