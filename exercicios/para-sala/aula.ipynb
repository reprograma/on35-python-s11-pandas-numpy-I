# %%
import pandas as pd

df = pd.read_csv('INMET_CO_DF_A001_BRASILIA_01-01-2023_A_31-12-2023.csv', delimiter=';', skiprows=8, encoding='latin1')

# %%
df.head()
# Out:
#          Data  Hora UTC PRECIPITAÇÃO TOTAL, HORÁRIO (mm)  \
# 0  01/01/2023  0000 UTC                                0
# 1  01/01/2023  0100 UTC                                0
# 2  01/01/2023  0200 UTC                                0
# 3  01/01/2023  0300 UTC                                0
# 4  01/01/2023  0400 UTC                                0
#
#   PRESSAO ATMOSFERICA AO NIVEL DA ESTACAO, HORARIA (mB)  \
# 0                                              887,7
# 1                                              888,1
# 2                                              887,8
# 3                                              887,8
# 4                                              887,6
#
#   PRESSÃO ATMOSFERICA MAX.NA HORA ANT. (AUT) (mB)  \
# 0                                           887,7
# 1                                           888,1
# 2                                           888,1
# 3                                           887,9
# ...

# %%
df.tail()
# Out:
#             Data  Hora UTC PRECIPITAÇÃO TOTAL, HORÁRIO (mm)  \
# 8755  2023/12/31  1900 UTC                                0
# 8756  2023/12/31  2000 UTC                                0
# 8757  2023/12/31  2100 UTC                                0
# 8758  2023/12/31  2200 UTC                                0
# 8759  2023/12/31  2300 UTC                                0
#
#      PRESSAO ATMOSFERICA AO NIVEL DA ESTACAO, HORARIA (mB)  \
# 8755                                              884,2
# 8756                                              883,7
# 8757                                              883,5
# 8758                                              884,5
# 8759                                              885,3
#
#      PRESSÃO ATMOSFERICA MAX.NA HORA ANT. (AUT) (mB)  \
# 8755                                           885,2
# 8756                                           884,3
# 8757                                           883,7
# ...

# %%
df.shape
# Out:
# (8760, 20)

# %%
df.describe()
# Out:
#        UMIDADE REL. MAX. NA HORA ANT. (AUT) (%)  \
# count                               8747.000000
# mean                                  68.326741
# std                                   19.268845
# min                                   19.000000
# 25%                                   54.000000
# 50%                                   70.000000
# 75%                                   86.000000
# max                                   98.000000
#
#        UMIDADE REL. MIN. NA HORA ANT. (AUT) (%)  \
# count                               8747.000000
# mean                                  61.435692
# std                                   19.837790
# min                                   16.000000
# 25%                                   46.000000
# 50%                                   61.000000
# 75%                                   79.000000
# max                                   98.000000
#
#        UMIDADE RELATIVA DO AR, HORARIA (%)  \
# ...

# %%
df.dtypes
# Out:
# Data                                                      object
# Hora UTC                                                  object
# PRECIPITAÇÃO TOTAL, HORÁRIO (mm)                          object
# PRESSAO ATMOSFERICA AO NIVEL DA ESTACAO, HORARIA (mB)     object
# PRESSÃO ATMOSFERICA MAX.NA HORA ANT. (AUT) (mB)           object
# PRESSÃO ATMOSFERICA MIN. NA HORA ANT. (AUT) (mB)          object
# RADIACAO GLOBAL (Kj/m²)                                   object
# TEMPERATURA DO AR - BULBO SECO, HORARIA (°C)              object
# TEMPERATURA DO PONTO DE ORVALHO (°C)                      object
# TEMPERATURA MÁXIMA NA HORA ANT. (AUT) (°C)                object
# TEMPERATURA MÍNIMA NA HORA ANT. (AUT) (°C)                object
# TEMPERATURA ORVALHO MAX. NA HORA ANT. (AUT) (°C)          object
# TEMPERATURA ORVALHO MIN. NA HORA ANT. (AUT) (°C)          object
# UMIDADE REL. MAX. NA HORA ANT. (AUT) (%)                 float64
# ...

# %%
df.sample()
# Out:
#             Data  Hora UTC PRECIPITAÇÃO TOTAL, HORÁRIO (mm)  \
# 6982  2023/10/18  2200 UTC                                0
#
#      PRESSAO ATMOSFERICA AO NIVEL DA ESTACAO, HORARIA (mB)  \
# 6982                                              885,6
#
#      PRESSÃO ATMOSFERICA MAX.NA HORA ANT. (AUT) (mB)  \
# 6982                                           885,7
#
#      PRESSÃO ATMOSFERICA MIN. NA HORA ANT. (AUT) (mB) RADIACAO GLOBAL (Kj/m²)  \
# 6982                                            885,1                     8,3
#
#      TEMPERATURA DO AR - BULBO SECO, HORARIA (°C)  \
# 6982                                         25,2
#
#      TEMPERATURA DO PONTO DE ORVALHO (°C)  \
# 6982                                  9,1
#
#      TEMPERATURA MÁXIMA NA HORA ANT. (AUT) (°C)  \
# 6982                                       29,8
#
#      TEMPERATURA MÍNIMA NA HORA ANT. (AUT) (°C)  \
# 6982                                       25,2
#
# ...

# %%
df.sample(5)
# Out:
#             Data  Hora UTC PRECIPITAÇÃO TOTAL, HORÁRIO (mm)  \
# 4304  2023/06/29  0800 UTC                                0
# 2945  2023/05/03  1700 UTC                                0
# 480   2023/01/21  0000 UTC                                0
# 3169  2023/05/13  0100 UTC                                0
# 2963  2023/05/04  1100 UTC                                0
#
#      PRESSAO ATMOSFERICA AO NIVEL DA ESTACAO, HORARIA (mB)  \
# 4304                                              890,6
# 2945                                              886,5
# 480                                               886,4
# 3169                                                889
# 2963                                              888,9
#
#      PRESSÃO ATMOSFERICA MAX.NA HORA ANT. (AUT) (mB)  \
# 4304                                           890,6
# 2945                                           887,1
# 480                                            886,4
# ...

# %%
df_reduzido = df[['Data', 'Hora UTC', 'PRECIPITAÇÃO TOTAL, HORÁRIO (mm)', 'TEMPERATURA MÁXIMA NA HORA ANT. (AUT) (°C)']]

# %%
df_reduzido.head()
# Out:
#          Data  Hora UTC PRECIPITAÇÃO TOTAL, HORÁRIO (mm)  \
# 0  2023/01/01  0000 UTC                                0
# 1  2023/01/01  0100 UTC                                0
# 2  2023/01/01  0200 UTC                                0
# 3  2023/01/01  0300 UTC                                0
# 4  2023/01/01  0400 UTC                                0
#
#   TEMPERATURA MÁXIMA NA HORA ANT. (AUT) (°C)
# 0                                       20,9
# 1                                       20,1
# 2                                       19,5
# 3                                       19,4
# 4                                       19,7

# %%
coluna_data = df['Data']

# %%
coluna_data.head(1)
# Out:
# 0    2023/01/01
# Name: Data, dtype: object

# %%
coluna_data.min()
# Out:
# '2023/01/01'

# %%
df.dtypes
# Out:
# Data                                                      object
# Hora UTC                                                  object
# PRECIPITAÇÃO TOTAL, HORÁRIO (mm)                          object
# PRESSAO ATMOSFERICA AO NIVEL DA ESTACAO, HORARIA (mB)     object
# PRESSÃO ATMOSFERICA MAX.NA HORA ANT. (AUT) (mB)           object
# PRESSÃO ATMOSFERICA MIN. NA HORA ANT. (AUT) (mB)          object
# RADIACAO GLOBAL (Kj/m²)                                   object
# TEMPERATURA DO AR - BULBO SECO, HORARIA (°C)              object
# TEMPERATURA DO PONTO DE ORVALHO (°C)                      object
# TEMPERATURA MÁXIMA NA HORA ANT. (AUT) (°C)                object
# TEMPERATURA MÍNIMA NA HORA ANT. (AUT) (°C)                object
# TEMPERATURA ORVALHO MAX. NA HORA ANT. (AUT) (°C)          object
# TEMPERATURA ORVALHO MIN. NA HORA ANT. (AUT) (°C)          object
# UMIDADE REL. MAX. NA HORA ANT. (AUT) (%)                 float64
# ...

# %%
coluna_umidade_relativa = df['UMIDADE REL. MIN. NA HORA ANT. (AUT) (%)']

# %%
coluna_umidade_relativa.min()
# Out:
# np.float64(16.0)

# %%
coluna_umidade_relativa.max()
# Out:
# np.float64(98.0)

# %%
coluna_umidade_relativa_conv = pd.to_numeric(df['UMIDADE REL. MIN. NA HORA ANT. (AUT) (%)'], errors='coerce')

# %%
coluna_umidade_relativa_conv.sum()
# Out:
# np.float64(61.435692237338515)

# %%
coluna_umidade_relativa_conv.mean()
# Out:
# np.float64(61.435692237338515)

# %%
df.isnull()
# Out:
#        Data  Hora UTC  PRECIPITAÇÃO TOTAL, HORÁRIO (mm)  \
# 0     False     False                             False
# 1     False     False                             False
# 2     False     False                             False
# 3     False     False                             False
# 4     False     False                             False
# ...     ...       ...                               ...
# 8755  False     False                             False
# 8756  False     False                             False
# 8757  False     False                             False
# 8758  False     False                             False
# 8759  False     False                             False
#
#       PRESSAO ATMOSFERICA AO NIVEL DA ESTACAO, HORARIA (mB)  \
# 0                                                 False
# 1                                                 False
# 2                                                 False
# 3                                                 False
# ...

# %%
df.isnull().sum() #total de registros nulos
# Out:
# Data                                                        0
# Hora UTC                                                    0
# PRECIPITAÇÃO TOTAL, HORÁRIO (mm)                            5
# PRESSAO ATMOSFERICA AO NIVEL DA ESTACAO, HORARIA (mB)       5
# PRESSÃO ATMOSFERICA MAX.NA HORA ANT. (AUT) (mB)            13
# PRESSÃO ATMOSFERICA MIN. NA HORA ANT. (AUT) (mB)           13
# RADIACAO GLOBAL (Kj/m²)                                  4087
# TEMPERATURA DO AR - BULBO SECO, HORARIA (°C)                5
# TEMPERATURA DO PONTO DE ORVALHO (°C)                        5
# TEMPERATURA MÁXIMA NA HORA ANT. (AUT) (°C)                 13
# TEMPERATURA MÍNIMA NA HORA ANT. (AUT) (°C)                 13
# TEMPERATURA ORVALHO MAX. NA HORA ANT. (AUT) (°C)           13
# TEMPERATURA ORVALHO MIN. NA HORA ANT. (AUT) (°C)           13
# UMIDADE REL. MAX. NA HORA ANT. (AUT) (%)                   13
# UMIDADE REL. MIN. NA HORA ANT. (AUT) (%)                   13
# ...

# %%
df_substituido = df.replace('0', 'nan')

# %%
df_substituido.head()
# Out:
#          Data  Hora UTC PRECIPITAÇÃO TOTAL, HORÁRIO (mm)  \
# 0  2023/01/01  0000 UTC                              nan
# 1  2023/01/01  0100 UTC                              nan
# 2  2023/01/01  0200 UTC                              nan
# 3  2023/01/01  0300 UTC                              nan
# 4  2023/01/01  0400 UTC                              nan
#
#   PRESSAO ATMOSFERICA AO NIVEL DA ESTACAO, HORARIA (mB)  \
# 0                                              887,7
# 1                                              888,1
# 2                                              887,8
# 3                                              887,8
# 4                                              887,6
#
#   PRESSÃO ATMOSFERICA MAX.NA HORA ANT. (AUT) (mB)  \
# 0                                           887,7
# 1                                           888,1
# 2                                           888,1
# 3                                           887,9
# ...

# %%
# Normaliza os valores de uma coluna para o intervalo [0, 1]
df['UMIDADE RELATIVA DO AR, HORARIA (%)'] = (df['UMIDADE RELATIVA DO AR, HORARIA (%)'] - df['UMIDADE RELATIVA DO AR, HORARIA (%)'].min()) / (df['UMIDADE RELATIVA DO AR, HORARIA (%)'].max() - df['UMIDADE RELATIVA DO AR, HORARIA (%)'].min())

# %%
df['UMIDADE RELATIVA DO AR, HORARIA (%)'].head()
# Out:
# 0    0.864198
# 1    0.901235
# 2    0.901235
# 3    0.913580
# 4    0.901235
# Name: UMIDADE RELATIVA DO AR, HORARIA (%), dtype: float64

# %%
import matplotlib.pyplot as plt
# Out:
# Matplotlib is building the font cache; this may take a moment.

# %%
df_20 = df.head(20)

# %%
plt.figure(figsize=(12, 6))
plt.plot(df_20['Hora UTC'], df_20['UMIDADE RELATIVA DO AR, HORARIA (%)'], marker='o', linestyle='-', color='g')
plt.xlabel('Hora UTC')
plt.ylabel('Umidade (%)')
plt.title('Umidade ao Longo do Tempo')
plt.xticks(rotation=90)
plt.tight_layout()
plt.show()

# %%
# Gráfico de Dispersão
plt.figure(figsize=(12, 6))
plt.scatter(df_20['TEMPERATURA DO AR - BULBO SECO, HORARIA (°C)'], df_20['UMIDADE RELATIVA DO AR, HORARIA (%)'], color='y')
plt.xlabel('Temperatura (°C)')
plt.ylabel('Umidade (%)')
plt.title('Temperatura x Umidade')
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(12, 6))
plt.bar(df_20['Hora UTC'], df_20['PRECIPITAÇÃO TOTAL, HORÁRIO (mm)'], color='r')
plt.xlabel('Hora UTC')
plt.ylabel('Precipitação (mm)')
plt.title('Precipitação ao Longo do Tempo')
plt.xticks(rotation=90)
plt.tight_layout()
plt.show()
