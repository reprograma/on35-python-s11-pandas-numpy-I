# %%
import pandas as pd
df = pd.read_csv('bonito_2021.csv', delimiter=';', skiprows=8, encoding='latin1')

# %%
df.head(10)
# Out:
#          Data  Hora UTC PRECIPITAÇÃO TOTAL, HORÁRIO (mm)  \
# 0  2021/01/01  0000 UTC                                0
# 1  2021/01/01  0100 UTC                                0
# 2  2021/01/01  0200 UTC                                0
# 3  2021/01/01  0300 UTC                                0
# 4  2021/01/01  0400 UTC                                0
# 5  2021/01/01  0500 UTC                                0
# 6  2021/01/01  0600 UTC                                0
# 7  2021/01/01  0700 UTC                                0
# 8  2021/01/01  0800 UTC                                0
# 9  2021/01/01  0900 UTC                                0
#
#   PRESSAO ATMOSFERICA AO NIVEL DA ESTACAO, HORARIA (mB)  \
# 0                                              974,9
# 1                                              975,7
# 2                                              975,5
# 3                                              975,3
# 4                                              974,8
# 5                                              974,6
# 6                                              974,2
# 7                                              974,2
# 8                                              974,8
# 9                                              975,7
#
#   PRESSÃO ATMOSFERICA MAX.NA HORA ANT. (AUT) (mB)  \
# 0                                           974,9
# 1                                           975,7
# 2                                           975,7
# 3                                           975,6
# 4                                           975,3
# 5                                           974,8
# 6                                           974,6
# 7                                           974,2
# 8                                           974,8
# 9                                           975,7
#
#   PRESSÃO ATMOSFERICA MIN. NA HORA ANT. (AUT) (mB) RADIACAO GLOBAL (Kj/m²)  \
# 0                                              974                     NaN
# 1                                            974,9                     NaN
# 2                                            975,5                     NaN
# 3                                            975,3                     NaN
# 4                                            974,8                     NaN
# 5                                            974,4                     NaN
# 6                                            974,2                     NaN
# 7                                              974                     NaN
# 8                                            974,2                     NaN
# 9                                            974,8                     1,7
#
#   TEMPERATURA DO AR - BULBO SECO, HORARIA (°C)  \
# 0                                         23,1
# 1                                         23,7
# 2                                         23,7
# 3                                         22,8
# 4                                         22,6
# 5                                         21,9
# 6                                           22
# 7                                         21,5
# 8                                         21,5
# 9                                         21,4
#
#   TEMPERATURA DO PONTO DE ORVALHO (°C)  \
# 0                                 22,3
# 1                                 22,6
# 2                                 22,8
# 3                                 21,5
# 4                                 21,4
# 5                                 21,1
# 6                                 21,3
# 7                                 20,8
# 8                                 21,1
# 9                                 20,8
#
#   TEMPERATURA MÁXIMA NA HORA ANT. (AUT) (°C)  \
# 0                                       23,6
# 1                                       23,7
# 2                                       23,8
# 3                                       23,8
# 4                                       22,9
# 5                                       22,8
# 6                                       22,2
# 7                                         22
# 8                                       21,5
# 9                                       21,8
#
#   TEMPERATURA MÍNIMA NA HORA ANT. (AUT) (°C)  \
# 0                                       22,9
# 1                                       23,1
# 2                                       23,5
# 3                                       22,8
# 4                                       22,5
# 5                                       21,9
# 6                                       21,8
# 7                                       21,5
# 8                                       20,9
# 9                                       21,3
#
#   TEMPERATURA ORVALHO MAX. NA HORA ANT. (AUT) (°C)  \
# 0                                             22,4
# 1                                             22,7
# 2                                             22,9
# 3                                             22,9
# 4                                             21,6
# 5                                             21,5
# 6                                             21,4
# 7                                             21,3
# 8                                             21,1
# 9                                             21,3
#
#   TEMPERATURA ORVALHO MIN. NA HORA ANT. (AUT) (°C)  \
# 0                                               22
# 1                                             22,3
# 2                                             22,5
# 3                                             21,5
# 4                                             21,1
# 5                                             20,9
# 6                                               21
# 7                                             20,7
# 8                                             20,3
# 9                                             20,8
#
#    UMIDADE REL. MAX. NA HORA ANT. (AUT) (%)  \
# 0                                      95.0
# 1                                      95.0
# 2                                      95.0
# 3                                      95.0
# 4                                      94.0
# 5                                      95.0
# 6                                      96.0
# 7                                      96.0
# 8                                      98.0
# 9                                      98.0
#
#    UMIDADE REL. MIN. NA HORA ANT. (AUT) (%)  \
# 0                                      93.0
# 1                                      94.0
# 2                                      93.0
# 3                                      91.0
# 4                                      90.0
# 5                                      92.0
# 6                                      94.0
# 7                                      94.0
# 8                                      96.0
# 9                                      96.0
#
#    UMIDADE RELATIVA DO AR, HORARIA (%)  VENTO, DIREÇÃO HORARIA (gr) (° (gr))  \
# 0                                 95.0                                 169.0
# 1                                 94.0                                 237.0
# 2                                 95.0                                  28.0
# 3                                 92.0                                 249.0
# 4                                 92.0                                 156.0
# 5                                 95.0                                 145.0
# 6                                 96.0                                 290.0
# 7                                 96.0                                 354.0
# 8                                 98.0                                 254.0
# 9                                 96.0                                 217.0
#
#   VENTO, RAJADA MAXIMA (m/s) VENTO, VELOCIDADE HORARIA (m/s)  Unnamed: 19
# 0                        2,9                               2          NaN
# 1                        2,7                              ,5          NaN
# 2                          2                              ,6          NaN
# 3                        3,1                             1,4          NaN
# 4                        3,5                             2,4          NaN
# 5                        3,5                             1,9          NaN
# 6                        2,9                               1          NaN
# 7                        2,3                               1          NaN
# 8                        2,3                              ,5          NaN
# 9                        2,3                             1,8          NaN

# %%
df.tail()
# Out:
#             Data  Hora UTC PRECIPITAÇÃO TOTAL, HORÁRIO (mm)  \
# 8755  2021/12/31  1900 UTC                              NaN
# 8756  2021/12/31  2000 UTC                              NaN
# 8757  2021/12/31  2100 UTC                              NaN
# 8758  2021/12/31  2200 UTC                              NaN
# 8759  2021/12/31  2300 UTC                              NaN
#
#      PRESSAO ATMOSFERICA AO NIVEL DA ESTACAO, HORARIA (mB)  \
# 8755                                                NaN
# 8756                                                NaN
# 8757                                                NaN
# 8758                                                NaN
# 8759                                                NaN
#
#      PRESSÃO ATMOSFERICA MAX.NA HORA ANT. (AUT) (mB)  \
# 8755                                             NaN
# 8756                                             NaN
# 8757                                             NaN
# 8758                                             NaN
# 8759                                             NaN
#
#      PRESSÃO ATMOSFERICA MIN. NA HORA ANT. (AUT) (mB) RADIACAO GLOBAL (Kj/m²)  \
# 8755                                              NaN                     NaN
# 8756                                              NaN                     NaN
# 8757                                              NaN                     NaN
# 8758                                              NaN                     NaN
# 8759                                              NaN                     NaN
#
#      TEMPERATURA DO AR - BULBO SECO, HORARIA (°C)  \
# 8755                                          NaN
# 8756                                          NaN
# 8757                                          NaN
# 8758                                          NaN
# 8759                                          NaN
#
#      TEMPERATURA DO PONTO DE ORVALHO (°C)  \
# 8755                                  NaN
# 8756                                  NaN
# 8757                                  NaN
# 8758                                  NaN
# 8759                                  NaN
#
#      TEMPERATURA MÁXIMA NA HORA ANT. (AUT) (°C)  \
# 8755                                        NaN
# 8756                                        NaN
# 8757                                        NaN
# 8758                                        NaN
# 8759                                        NaN
#
#      TEMPERATURA MÍNIMA NA HORA ANT. (AUT) (°C)  \
# 8755                                        NaN
# 8756                                        NaN
# 8757                                        NaN
# 8758                                        NaN
# 8759                                        NaN
#
#      TEMPERATURA ORVALHO MAX. NA HORA ANT. (AUT) (°C)  \
# 8755                                              NaN
# 8756                                              NaN
# 8757                                              NaN
# 8758                                              NaN
# 8759                                              NaN
#
#      TEMPERATURA ORVALHO MIN. NA HORA ANT. (AUT) (°C)  \
# 8755                                              NaN
# 8756                                              NaN
# 8757                                              NaN
# 8758                                              NaN
# 8759                                              NaN
#
#       UMIDADE REL. MAX. NA HORA ANT. (AUT) (%)  \
# 8755                                       NaN
# 8756                                       NaN
# 8757                                       NaN
# 8758                                       NaN
# 8759                                       NaN
#
#       UMIDADE REL. MIN. NA HORA ANT. (AUT) (%)  \
# 8755                                       NaN
# 8756                                       NaN
# 8757                                       NaN
# 8758                                       NaN
# 8759                                       NaN
#
#       UMIDADE RELATIVA DO AR, HORARIA (%)  \
# 8755                                  NaN
# 8756                                  NaN
# 8757                                  NaN
# 8758                                  NaN
# 8759                                  NaN
#
#       VENTO, DIREÇÃO HORARIA (gr) (° (gr)) VENTO, RAJADA MAXIMA (m/s)  \
# 8755                                   NaN                        NaN
# 8756                                   NaN                        NaN
# 8757                                   NaN                        NaN
# 8758                                   NaN                        NaN
# 8759                                   NaN                        NaN
#
#      VENTO, VELOCIDADE HORARIA (m/s)  Unnamed: 19
# 8755                             NaN          NaN
# 8756                             NaN          NaN
# 8757                             NaN          NaN
# 8758                             NaN          NaN
# 8759                             NaN          NaN

# %%
df.shape
# Out:
# (8760, 20)

# %%
df. describe()
# Out:
#        UMIDADE REL. MAX. NA HORA ANT. (AUT) (%)  \
# count                               4412.000000
# mean                                  78.476428
# std                                   17.573517
# min                                   31.000000
# 25%                                   65.000000
# 50%                                   84.000000
# 75%                                   93.000000
# max                                   99.000000
#
#        UMIDADE REL. MIN. NA HORA ANT. (AUT) (%)  \
# count                               4412.000000
# mean                                  71.950363
# std                                   19.298242
# min                                   23.000000
# 25%                                   56.000000
# 50%                                   76.000000
# 75%                                   89.000000
# max                                   99.000000
#
#        UMIDADE RELATIVA DO AR, HORARIA (%)  \
# count                          4413.000000
# mean                             75.178790
# std                              18.572662
# min                              25.000000
# 25%                              61.000000
# 50%                              80.000000
# 75%                              91.000000
# max                              99.000000
#
#        VENTO, DIREÇÃO HORARIA (gr) (° (gr))  Unnamed: 19
# count                           4413.000000          0.0
# mean                             176.038296          NaN
# std                              112.895151          NaN
# min                                1.000000          NaN
# 25%                               59.000000          NaN
# 50%                              195.000000          NaN
# 75%                              263.000000          NaN
# max                              360.000000          NaN

# %%
df.dtypes
# Out:
# Data                                                      object
# Hora UTC                                                  object
# PRECIPITAÇÃO TOTAL, HORÁRIO (mm)                          object
# PRESSAO ATMOSFERICA AO NIVEL DA ESTACAO, HORARIA (mB)     object
# PRESSÃO ATMOSFERICA MAX.NA HORA ANT. (AUT) (mB)           object
# PRESSÃO ATMOSFERICA MIN. NA HORA ANT. (AUT) (mB)          object
# RADIACAO GLOBAL (Kj/m²)                                   object
# TEMPERATURA DO AR - BULBO SECO, HORARIA (°C)              object
# TEMPERATURA DO PONTO DE ORVALHO (°C)                      object
# TEMPERATURA MÁXIMA NA HORA ANT. (AUT) (°C)                object
# TEMPERATURA MÍNIMA NA HORA ANT. (AUT) (°C)                object
# TEMPERATURA ORVALHO MAX. NA HORA ANT. (AUT) (°C)          object
# TEMPERATURA ORVALHO MIN. NA HORA ANT. (AUT) (°C)          object
# UMIDADE REL. MAX. NA HORA ANT. (AUT) (%)                 float64
# UMIDADE REL. MIN. NA HORA ANT. (AUT) (%)                 float64
# UMIDADE RELATIVA DO AR, HORARIA (%)                      float64
# VENTO, DIREÇÃO HORARIA (gr) (° (gr))                     float64
# VENTO, RAJADA MAXIMA (m/s)                                object
# VENTO, VELOCIDADE HORARIA (m/s)                           object
# Unnamed: 19                                              float64
# dtype: object

# %%
df.sample()
# Out:
#             Data  Hora UTC PRECIPITAÇÃO TOTAL, HORÁRIO (mm)  \
# 6985  2021/10/19  0100 UTC                              NaN
#
#      PRESSAO ATMOSFERICA AO NIVEL DA ESTACAO, HORARIA (mB)  \
# 6985                                                NaN
#
#      PRESSÃO ATMOSFERICA MAX.NA HORA ANT. (AUT) (mB)  \
# 6985                                             NaN
#
#      PRESSÃO ATMOSFERICA MIN. NA HORA ANT. (AUT) (mB) RADIACAO GLOBAL (Kj/m²)  \
# 6985                                              NaN                     NaN
#
#      TEMPERATURA DO AR - BULBO SECO, HORARIA (°C)  \
# 6985                                          NaN
#
#      TEMPERATURA DO PONTO DE ORVALHO (°C)  \
# 6985                                  NaN
#
#      TEMPERATURA MÁXIMA NA HORA ANT. (AUT) (°C)  \
# 6985                                        NaN
#
#      TEMPERATURA MÍNIMA NA HORA ANT. (AUT) (°C)  \
# 6985                                        NaN
#
#      TEMPERATURA ORVALHO MAX. NA HORA ANT. (AUT) (°C)  \
# 6985                                              NaN
#
#      TEMPERATURA ORVALHO MIN. NA HORA ANT. (AUT) (°C)  \
# 6985                                              NaN
#
#       UMIDADE REL. MAX. NA HORA ANT. (AUT) (%)  \
# 6985                                       NaN
#
#       UMIDADE REL. MIN. NA HORA ANT. (AUT) (%)  \
# 6985                                       NaN
#
#       UMIDADE RELATIVA DO AR, HORARIA (%)  \
# 6985                                  NaN
#
#       VENTO, DIREÇÃO HORARIA (gr) (° (gr)) VENTO, RAJADA MAXIMA (m/s)  \
# 6985                                   NaN                        NaN
#
#      VENTO, VELOCIDADE HORARIA (m/s)  Unnamed: 19
# 6985                             NaN          NaN

# %%
df_reduzido = df[['Data', 'Hora UTC', 'PRECIPITAÇÃO TOTAL, HORÁRIO (mm)', 'TEMPERATURA MÁXIMA NA HORA ANT. (AUT) (°C)']]

# %%
df_reduzido.head()
# Out:
#          Data  Hora UTC PRECIPITAÇÃO TOTAL, HORÁRIO (mm)  \
# 0  2021/01/01  0000 UTC                                0
# 1  2021/01/01  0100 UTC                                0
# 2  2021/01/01  0200 UTC                                0
# 3  2021/01/01  0300 UTC                                0
# 4  2021/01/01  0400 UTC                                0
#
#   TEMPERATURA MÁXIMA NA HORA ANT. (AUT) (°C)
# 0                                       23,6
# 1                                       23,7
# 2                                       23,8
# 3                                       23,8
# 4                                       22,9

# %%
coluna_data = df['Data']

# %%
coluna_data.head(1)
# Out:
# 0    2021/01/01
# Name: Data, dtype: object

# %%
coluna_data.min()
# Out:
# '2021/01/01'

# %%
coluna_umidade_relativa = df ['UMIDADE RELATIVA DO AR, HORARIA (%)']

# %%
coluna_umidade_relativa.min()
# Out:
# np.float64(25.0)

# %%
coluna_umidade_relativa.max()
# Out:
# np.float64(99.0)

# %%
coluna_umidade_relativa.sum()
# Out:
# np.float64(331764.0)

# %%
coluna_umidade_relativa.mean()
# Out:
# np.float64(75.17878993881713)

# %%
coluna_umidade_relativa.head()
# Out:
# 0    95.0
# 1    94.0
# 2    95.0
# 3    92.0
# 4    92.0
# Name: UMIDADE RELATIVA DO AR, HORARIA (%), dtype: float64

# %%
df.isnull().sum()
# Out:
# Data                                                        0
# Hora UTC                                                    0
# PRECIPITAÇÃO TOTAL, HORÁRIO (mm)                         4347
# PRESSAO ATMOSFERICA AO NIVEL DA ESTACAO, HORARIA (mB)    4347
# PRESSÃO ATMOSFERICA MAX.NA HORA ANT. (AUT) (mB)          4348
# PRESSÃO ATMOSFERICA MIN. NA HORA ANT. (AUT) (mB)         4348
# RADIACAO GLOBAL (Kj/m²)                                  6270
# TEMPERATURA DO AR - BULBO SECO, HORARIA (°C)             4347
# TEMPERATURA DO PONTO DE ORVALHO (°C)                     4347
# TEMPERATURA MÁXIMA NA HORA ANT. (AUT) (°C)               4348
# TEMPERATURA MÍNIMA NA HORA ANT. (AUT) (°C)               4348
# TEMPERATURA ORVALHO MAX. NA HORA ANT. (AUT) (°C)         4348
# TEMPERATURA ORVALHO MIN. NA HORA ANT. (AUT) (°C)         4348
# UMIDADE REL. MAX. NA HORA ANT. (AUT) (%)                 4348
# UMIDADE REL. MIN. NA HORA ANT. (AUT) (%)                 4348
# UMIDADE RELATIVA DO AR, HORARIA (%)                      4347
# VENTO, DIREÇÃO HORARIA (gr) (° (gr))                     4347
# VENTO, RAJADA MAXIMA (m/s)                               4357
# VENTO, VELOCIDADE HORARIA (m/s)                          4347
# Unnamed: 19                                              8760
# dtype: int64

# %%
remover = df.dropna(axis=0, how='all')
remover
# Out:
#             Data  Hora UTC PRECIPITAÇÃO TOTAL, HORÁRIO (mm)  \
# 0     2021/01/01  0000 UTC                                0
# 1     2021/01/01  0100 UTC                                0
# 2     2021/01/01  0200 UTC                                0
# 3     2021/01/01  0300 UTC                                0
# 4     2021/01/01  0400 UTC                                0
# ...          ...       ...                              ...
# 8755  2021/12/31  1900 UTC                              NaN
# 8756  2021/12/31  2000 UTC                              NaN
# 8757  2021/12/31  2100 UTC                              NaN
# 8758  2021/12/31  2200 UTC                              NaN
# 8759  2021/12/31  2300 UTC                              NaN
#
#      PRESSAO ATMOSFERICA AO NIVEL DA ESTACAO, HORARIA (mB)  \
# 0                                                 974,9
# 1                                                 975,7
# 2                                                 975,5
# 3                                                 975,3
# 4                                                 974,8
# ...                                                 ...
# 8755                                                NaN
# 8756                                                NaN
# 8757                                                NaN
# 8758                                                NaN
# 8759                                                NaN
#
#      PRESSÃO ATMOSFERICA MAX.NA HORA ANT. (AUT) (mB)  \
# 0                                              974,9
# 1                                              975,7
# 2                                              975,7
# 3                                              975,6
# 4                                              975,3
# ...                                              ...
# 8755                                             NaN
# 8756                                             NaN
# 8757                                             NaN
# 8758                                             NaN
# 8759                                             NaN
#
#      PRESSÃO ATMOSFERICA MIN. NA HORA ANT. (AUT) (mB) RADIACAO GLOBAL (Kj/m²)  \
# 0                                                 974                     NaN
# 1                                               974,9                     NaN
# 2                                               975,5                     NaN
# 3                                               975,3                     NaN
# 4                                               974,8                     NaN
# ...                                               ...                     ...
# 8755                                              NaN                     NaN
# 8756                                              NaN                     NaN
# 8757                                              NaN                     NaN
# 8758                                              NaN                     NaN
# 8759                                              NaN                     NaN
#
#      TEMPERATURA DO AR - BULBO SECO, HORARIA (°C)  \
# 0                                            23,1
# 1                                            23,7
# 2                                            23,7
# 3                                            22,8
# 4                                            22,6
# ...                                           ...
# 8755                                          NaN
# 8756                                          NaN
# 8757                                          NaN
# 8758                                          NaN
# 8759                                          NaN
#
#      TEMPERATURA DO PONTO DE ORVALHO (°C)  \
# 0                                    22,3
# 1                                    22,6
# 2                                    22,8
# 3                                    21,5
# 4                                    21,4
# ...                                   ...
# 8755                                  NaN
# 8756                                  NaN
# 8757                                  NaN
# 8758                                  NaN
# 8759                                  NaN
#
#      TEMPERATURA MÁXIMA NA HORA ANT. (AUT) (°C)  \
# 0                                          23,6
# 1                                          23,7
# 2                                          23,8
# 3                                          23,8
# 4                                          22,9
# ...                                         ...
# 8755                                        NaN
# 8756                                        NaN
# 8757                                        NaN
# 8758                                        NaN
# 8759                                        NaN
#
#      TEMPERATURA MÍNIMA NA HORA ANT. (AUT) (°C)  \
# 0                                          22,9
# 1                                          23,1
# 2                                          23,5
# 3                                          22,8
# 4                                          22,5
# ...                                         ...
# 8755                                        NaN
# 8756                                        NaN
# 8757                                        NaN
# 8758                                        NaN
# 8759                                        NaN
#
#      TEMPERATURA ORVALHO MAX. NA HORA ANT. (AUT) (°C)  \
# 0                                                22,4
# 1                                                22,7
# 2                                                22,9
# 3                                                22,9
# 4                                                21,6
# ...                                               ...
# 8755                                              NaN
# 8756                                              NaN
# 8757                                              NaN
# 8758                                              NaN
# 8759                                              NaN
#
#      TEMPERATURA ORVALHO MIN. NA HORA ANT. (AUT) (°C)  \
# 0                                                  22
# 1                                                22,3
# 2                                                22,5
# 3                                                21,5
# 4                                                21,1
# ...                                               ...
# 8755                                              NaN
# 8756                                              NaN
# 8757                                              NaN
# 8758                                              NaN
# 8759                                              NaN
#
#       UMIDADE REL. MAX. NA HORA ANT. (AUT) (%)  \
# 0                                         95.0
# 1                                         95.0
# 2                                         95.0
# 3                                         95.0
# 4                                         94.0
# ...                                        ...
# 8755                                       NaN
# 8756                                       NaN
# 8757                                       NaN
# 8758                                       NaN
# 8759                                       NaN
#
#       UMIDADE REL. MIN. NA HORA ANT. (AUT) (%)  \
# 0                                         93.0
# 1                                         94.0
# 2                                         93.0
# 3                                         91.0
# 4                                         90.0
# ...                                        ...
# 8755                                       NaN
# 8756                                       NaN
# 8757                                       NaN
# 8758                                       NaN
# 8759                                       NaN
#
#       UMIDADE RELATIVA DO AR, HORARIA (%)  \
# 0                                    95.0
# 1                                    94.0
# 2                                    95.0
# 3                                    92.0
# 4                                    92.0
# ...                                   ...
# 8755                                  NaN
# 8756                                  NaN
# 8757                                  NaN
# 8758                                  NaN
# 8759                                  NaN
#
#       VENTO, DIREÇÃO HORARIA (gr) (° (gr)) VENTO, RAJADA MAXIMA (m/s)  \
# 0                                    169.0                        2,9
# 1                                    237.0                        2,7
# 2                                     28.0                          2
# 3                                    249.0                        3,1
# 4                                    156.0                        3,5
# ...                                    ...                        ...
# 8755                                   NaN                        NaN
# 8756                                   NaN                        NaN
# 8757                                   NaN                        NaN
# 8758                                   NaN                        NaN
# 8759                                   NaN                        NaN
#
#      VENTO, VELOCIDADE HORARIA (m/s)  Unnamed: 19
# 0                                  2          NaN
# 1                                 ,5          NaN
# 2                                 ,6          NaN
# 3                                1,4          NaN
# 4                                2,4          NaN
# ...                              ...          ...
# 8755                             NaN          NaN
# 8756                             NaN          NaN
# 8757                             NaN          NaN
# 8758                             NaN          NaN
# 8759                             NaN          NaN
#
# [8760 rows x 20 columns]

# %%
df_substituido = df.replace('0','-1')

# %%
df_substituido.head(9)
# Out:
#          Data  Hora UTC PRECIPITAÇÃO TOTAL, HORÁRIO (mm)  \
# 0  2021/01/01  0000 UTC                               -1
# 1  2021/01/01  0100 UTC                               -1
# 2  2021/01/01  0200 UTC                               -1
# 3  2021/01/01  0300 UTC                               -1
# 4  2021/01/01  0400 UTC                               -1
# 5  2021/01/01  0500 UTC                               -1
# 6  2021/01/01  0600 UTC                               -1
# 7  2021/01/01  0700 UTC                               -1
# 8  2021/01/01  0800 UTC                               -1
#
#   PRESSAO ATMOSFERICA AO NIVEL DA ESTACAO, HORARIA (mB)  \
# 0                                              974,9
# 1                                              975,7
# 2                                              975,5
# 3                                              975,3
# 4                                              974,8
# 5                                              974,6
# 6                                              974,2
# 7                                              974,2
# 8                                              974,8
#
#   PRESSÃO ATMOSFERICA MAX.NA HORA ANT. (AUT) (mB)  \
# 0                                           974,9
# 1                                           975,7
# 2                                           975,7
# 3                                           975,6
# 4                                           975,3
# 5                                           974,8
# 6                                           974,6
# 7                                           974,2
# 8                                           974,8
#
#   PRESSÃO ATMOSFERICA MIN. NA HORA ANT. (AUT) (mB) RADIACAO GLOBAL (Kj/m²)  \
# 0                                              974                     NaN
# 1                                            974,9                     NaN
# 2                                            975,5                     NaN
# 3                                            975,3                     NaN
# 4                                            974,8                     NaN
# 5                                            974,4                     NaN
# 6                                            974,2                     NaN
# 7                                              974                     NaN
# 8                                            974,2                     NaN
#
#   TEMPERATURA DO AR - BULBO SECO, HORARIA (°C)  \
# 0                                         23,1
# 1                                         23,7
# 2                                         23,7
# 3                                         22,8
# 4                                         22,6
# 5                                         21,9
# 6                                           22
# 7                                         21,5
# 8                                         21,5
#
#   TEMPERATURA DO PONTO DE ORVALHO (°C)  \
# 0                                 22,3
# 1                                 22,6
# 2                                 22,8
# 3                                 21,5
# 4                                 21,4
# 5                                 21,1
# 6                                 21,3
# 7                                 20,8
# 8                                 21,1
#
#   TEMPERATURA MÁXIMA NA HORA ANT. (AUT) (°C)  \
# 0                                       23,6
# 1                                       23,7
# 2                                       23,8
# 3                                       23,8
# 4                                       22,9
# 5                                       22,8
# 6                                       22,2
# 7                                         22
# 8                                       21,5
#
#   TEMPERATURA MÍNIMA NA HORA ANT. (AUT) (°C)  \
# 0                                       22,9
# 1                                       23,1
# 2                                       23,5
# 3                                       22,8
# 4                                       22,5
# 5                                       21,9
# 6                                       21,8
# 7                                       21,5
# 8                                       20,9
#
#   TEMPERATURA ORVALHO MAX. NA HORA ANT. (AUT) (°C)  \
# 0                                             22,4
# 1                                             22,7
# 2                                             22,9
# 3                                             22,9
# 4                                             21,6
# 5                                             21,5
# 6                                             21,4
# 7                                             21,3
# 8                                             21,1
#
#   TEMPERATURA ORVALHO MIN. NA HORA ANT. (AUT) (°C)  \
# 0                                               22
# 1                                             22,3
# 2                                             22,5
# 3                                             21,5
# 4                                             21,1
# 5                                             20,9
# 6                                               21
# 7                                             20,7
# 8                                             20,3
#
#    UMIDADE REL. MAX. NA HORA ANT. (AUT) (%)  \
# 0                                      95.0
# 1                                      95.0
# 2                                      95.0
# 3                                      95.0
# 4                                      94.0
# 5                                      95.0
# 6                                      96.0
# 7                                      96.0
# 8                                      98.0
#
#    UMIDADE REL. MIN. NA HORA ANT. (AUT) (%)  \
# 0                                      93.0
# 1                                      94.0
# 2                                      93.0
# 3                                      91.0
# 4                                      90.0
# 5                                      92.0
# 6                                      94.0
# 7                                      94.0
# 8                                      96.0
#
#    UMIDADE RELATIVA DO AR, HORARIA (%)  VENTO, DIREÇÃO HORARIA (gr) (° (gr))  \
# 0                                 95.0                                 169.0
# 1                                 94.0                                 237.0
# 2                                 95.0                                  28.0
# 3                                 92.0                                 249.0
# 4                                 92.0                                 156.0
# 5                                 95.0                                 145.0
# 6                                 96.0                                 290.0
# 7                                 96.0                                 354.0
# 8                                 98.0                                 254.0
#
#   VENTO, RAJADA MAXIMA (m/s) VENTO, VELOCIDADE HORARIA (m/s)  Unnamed: 19
# 0                        2,9                               2          NaN
# 1                        2,7                              ,5          NaN
# 2                          2                              ,6          NaN
# 3                        3,1                             1,4          NaN
# 4                        3,5                             2,4          NaN
# 5                        3,5                             1,9          NaN
# 6                        2,9                               1          NaN
# 7                        2,3                               1          NaN
# 8                        2,3                              ,5          NaN

# %%
df.dtypes
# Out:
# Data                                                      object
# Hora UTC                                                  object
# PRECIPITAÇÃO TOTAL, HORÁRIO (mm)                          object
# PRESSAO ATMOSFERICA AO NIVEL DA ESTACAO, HORARIA (mB)     object
# PRESSÃO ATMOSFERICA MAX.NA HORA ANT. (AUT) (mB)           object
# PRESSÃO ATMOSFERICA MIN. NA HORA ANT. (AUT) (mB)          object
# RADIACAO GLOBAL (Kj/m²)                                   object
# TEMPERATURA DO AR - BULBO SECO, HORARIA (°C)              object
# TEMPERATURA DO PONTO DE ORVALHO (°C)                      object
# TEMPERATURA MÁXIMA NA HORA ANT. (AUT) (°C)                object
# TEMPERATURA MÍNIMA NA HORA ANT. (AUT) (°C)                object
# TEMPERATURA ORVALHO MAX. NA HORA ANT. (AUT) (°C)          object
# TEMPERATURA ORVALHO MIN. NA HORA ANT. (AUT) (°C)          object
# UMIDADE REL. MAX. NA HORA ANT. (AUT) (%)                 float64
# UMIDADE REL. MIN. NA HORA ANT. (AUT) (%)                 float64
# UMIDADE RELATIVA DO AR, HORARIA (%)                      float64
# VENTO, DIREÇÃO HORARIA (gr) (° (gr))                     float64
# VENTO, RAJADA MAXIMA (m/s)                                object
# VENTO, VELOCIDADE HORARIA (m/s)                           object
# Unnamed: 19                                              float64
# dtype: object

# %%
coluna_temperatura_maxima = df ['TEMPERATURA MÁXIMA NA HORA ANT. (AUT) (°C)']

# %%
coluna_temperatura_maxima = pd.to_numeric(df['TEMPERATURA MÁXIMA NA HORA ANT. (AUT) (°C)'], errors='coerce')
coluna_temperatura_maxima.min()
# Out:
# np.float64(11.0)

# %%
coluna_temperatura_maxima.max()
# Out:
# np.float64(37.0)

# %%
coluna_temperatura_maxima.sum()
# Out:
# np.float64(11410.0)

# %%
coluna_temperatura_maxima.mean()
# Out:
# np.float64(24.59051724137931)

# %%
coluna_temperatura_maxima.head()
# Out:
# 0   NaN
# 1   NaN
# 2   NaN
# 3   NaN
# 4   NaN
# Name: TEMPERATURA MÁXIMA NA HORA ANT. (AUT) (°C), dtype: float64

# %%
df.isnull().sum()
# Out:
# Data                                                        0
# Hora UTC                                                    0
# PRECIPITAÇÃO TOTAL, HORÁRIO (mm)                         4347
# PRESSAO ATMOSFERICA AO NIVEL DA ESTACAO, HORARIA (mB)    4347
# PRESSÃO ATMOSFERICA MAX.NA HORA ANT. (AUT) (mB)          4348
# PRESSÃO ATMOSFERICA MIN. NA HORA ANT. (AUT) (mB)         4348
# RADIACAO GLOBAL (Kj/m²)                                  6270
# TEMPERATURA DO AR - BULBO SECO, HORARIA (°C)             4347
# TEMPERATURA DO PONTO DE ORVALHO (°C)                     4347
# TEMPERATURA MÁXIMA NA HORA ANT. (AUT) (°C)               4348
# TEMPERATURA MÍNIMA NA HORA ANT. (AUT) (°C)               4348
# TEMPERATURA ORVALHO MAX. NA HORA ANT. (AUT) (°C)         4348
# TEMPERATURA ORVALHO MIN. NA HORA ANT. (AUT) (°C)         4348
# UMIDADE REL. MAX. NA HORA ANT. (AUT) (%)                 4348
# UMIDADE REL. MIN. NA HORA ANT. (AUT) (%)                 4348
# UMIDADE RELATIVA DO AR, HORARIA (%)                      4347
# VENTO, DIREÇÃO HORARIA (gr) (° (gr))                     4347
# VENTO, RAJADA MAXIMA (m/s)                               4357
# VENTO, VELOCIDADE HORARIA (m/s)                          4347
# Unnamed: 19                                              8760
# dtype: int64

# %%
df['Coluna1_normalizada'] = (df['UMIDADE RELATIVA DO AR, HORARIA (%)'] - df['UMIDADE RELATIVA DO AR, HORARIA (%)'].min()) / (df['UMIDADE RELATIVA DO AR, HORARIA (%)'].max() - df['UMIDADE RELATIVA DO AR, HORARIA (%)'].min())

# %%
df['Coluna1_normalizada'].head(20)
# Out:
# 0     0.945946
# 1     0.932432
# 2     0.945946
# 3     0.905405
# 4     0.905405
# 5     0.945946
# 6     0.959459
# 7     0.959459
# 8     0.986486
# 9     0.959459
# 10    0.891892
# 11    0.770270
# 12    0.689189
# 13    0.581081
# 14    0.513514
# 15    0.405405
# 16    0.459459
# 17    0.581081
# 18    0.364865
# 19    0.324324
# Name: Coluna1_normalizada, dtype: float64

# %%
import matplotlib.pyplot as plt

# %%
df_20 = df.head(20)

plt.figure(figsize=(12, 6))
plt.plot(df_20['Hora UTC'], df_20['TEMPERATURA DO AR - BULBO SECO, HORARIA (°C)'], marker='o', linestyle='-', color='b')
plt.xlabel('Hora UTC')
plt.ylabel('Temperatura (°C)')
plt.title('Temperatura ao Longo do Tempo')
plt.xticks(rotation=90)
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(12, 6))
plt.plot(df_20['Hora UTC'], df_20['UMIDADE RELATIVA DO AR, HORARIA (%)'], marker='o', linestyle='-', color='g')
plt.xlabel('Hora UTC')
plt.ylabel('Umidade (%)')
plt.title('Umidade ao Longo do Tempo')
plt.xticks(rotation=90)
plt.tight_layout()
plt.show()

# %%
# Gráfico de Dispersão

plt.figure(figsize=(12, 6))
plt.scatter(df_20['TEMPERATURA DO AR - BULBO SECO, HORARIA (°C)'], df_20['UMIDADE RELATIVA DO AR, HORARIA (%)'], color='y')
plt.xlabel('Temperatura (°C)')
plt.ylabel('Umidade (%)')
plt.title('Temperatura x Umidade')
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(12, 6))
plt.bar(df_20['Hora UTC'], df_20['PRECIPITAÇÃO TOTAL, HORÁRIO (mm)'], color='r')
plt.xlabel('Hora UTC')
plt.ylabel('Precipitação (mm)')
plt.title('Precipitação ao Longo do Tempo')
plt.xticks(rotation=90)
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(12, 6))
plt.hist(df_20['TEMPERATURA DO AR - BULBO SECO, HORARIA (°C)'], bins=10, color='c')
plt.xlabel('Temperatura (°C)')
plt.ylabel('Frequência')
plt.title('Histograma da Temperatura')
plt.tight_layout()
plt.show()
