# %%
import pandas as pd

df = pd.read_csv('brasilia_2020.csv', delimiter=';', skiprows=8, encoding='latin1')

# %%
df_amostra = df.sample(n=20)

# %%
df_amostra.head()
# Out:
#             Data  Hora UTC PRECIPITAÇÃO TOTAL, HORÁRIO (mm)  \
# 7995  2020/11/29  0300 UTC                                0
# 7648  2020/11/14  1600 UTC                                0
# 4298  2020/06/28  0200 UTC                                0
# 3197  2020/05/13  0500 UTC                                0
# 4297  2020/06/28  0100 UTC                                0
#
#      PRESSAO ATMOSFERICA AO NIVEL DA ESTACAO, HORARIA (mB)  \
# 7995                                              888,7
# 7648                                              886,1
# 4298                                              888,7
# 3197                                              887,6
# 4297                                              888,6
#
#      PRESSÃO ATMOSFERICA MAX.NA HORA ANT. (AUT) (mB)  \
# 7995                                           889,3
# 7648                                           886,8
# 4298                                           888,7
# ...

# %%
f_amostra = df_amostra[['Data', 'Hora UTC', 'TEMPERATURA DO AR - BULBO SECO, HORARIA (°C)', 'UMIDADE RELATIVA DO AR, HORARIA (%)', 'PRECIPITAÇÃO TOTAL, HORÁRIO (mm)']]

# %%
df_amostra
# Out:
#             Data  Hora UTC PRECIPITAÇÃO TOTAL, HORÁRIO (mm)  \
# 1562  2020/03/06  0200 UTC                                0
# 6849  2020/10/12  0900 UTC                                0
# 7771  2020/11/19  1900 UTC                                0
# 7960  2020/11/27  1600 UTC                                0
# 6752  2020/10/08  0800 UTC                                0
# 4150  2020/06/21  2200 UTC                                0
# 7504  2020/11/08  1600 UTC                                0
# 4870  2020/07/21  2200 UTC                                0
# 1482  2020/03/02  1800 UTC                               ,8
# 3806  2020/06/07  1400 UTC                                0
# 4514  2020/07/07  0200 UTC                                0
# 1619  2020/03/08  1100 UTC                                0
# 2196  2020/04/01  1200 UTC                                0
# 1697  2020/03/11  1700 UTC                                0
# 4943  2020/07/24  2300 UTC                                0
# ...

# %%
f_amostra['TEMPERATURA DO AR - BULBO SECO, HORARIA (°C)'] = df_amostra['TEMPERATURA DO AR - BULBO SECO, HORARIA (°C)'].replace(',', '.', regex=True)
# Out:
# C:\Users\annea\AppData\Local\Temp\ipykernel_9288\3308982152.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   f_amostra['TEMPERATURA DO AR - BULBO SECO, HORARIA (°C)'] = df_amostra['TEMPERATURA DO AR - BULBO SECO, HORARIA (°C)'].replace(',', '.', regex=True)

# %%
df_amostra['PRECIPITAÇÃO TOTAL, HORÁRIO (mm)'] = df_amostra['PRECIPITAÇÃO TOTAL, HORÁRIO (mm)'].replace(',', '.', regex=True)

# %%
df_amostra.head()
# Out:
#             Data  Hora UTC PRECIPITAÇÃO TOTAL, HORÁRIO (mm)  \
# 1562  2020/03/06  0200 UTC                                0
# 6849  2020/10/12  0900 UTC                                0
# 7771  2020/11/19  1900 UTC                                0
# 7960  2020/11/27  1600 UTC                                0
# 6752  2020/10/08  0800 UTC                                0
#
#      PRESSAO ATMOSFERICA AO NIVEL DA ESTACAO, HORARIA (mB)  \
# 1562                                              888,5
# 6849                                              888,5
# 7771                                                882
# 7960                                              888,3
# 6752                                                887
#
#      PRESSÃO ATMOSFERICA MAX.NA HORA ANT. (AUT) (mB)  \
# 1562                                           888,5
# 6849                                           888,5
# 7771                                             883
# ...

# %%
df_amostra.dtypes
# Out:
# Data                                                      object
# Hora UTC                                                  object
# PRECIPITAÇÃO TOTAL, HORÁRIO (mm)                          object
# PRESSAO ATMOSFERICA AO NIVEL DA ESTACAO, HORARIA (mB)     object
# PRESSÃO ATMOSFERICA MAX.NA HORA ANT. (AUT) (mB)           object
# PRESSÃO ATMOSFERICA MIN. NA HORA ANT. (AUT) (mB)          object
# RADIACAO GLOBAL (Kj/m²)                                   object
# TEMPERATURA DO AR - BULBO SECO, HORARIA (°C)              object
# TEMPERATURA DO PONTO DE ORVALHO (°C)                      object
# TEMPERATURA MÁXIMA NA HORA ANT. (AUT) (°C)                object
# TEMPERATURA MÍNIMA NA HORA ANT. (AUT) (°C)                object
# TEMPERATURA ORVALHO MAX. NA HORA ANT. (AUT) (°C)          object
# TEMPERATURA ORVALHO MIN. NA HORA ANT. (AUT) (°C)          object
# UMIDADE REL. MAX. NA HORA ANT. (AUT) (%)                   int64
# ...

# %%
f_amostra['TEMPERATURA DO AR - BULBO SECO, HORARIA (°C)'] = pd.to_numeric(df_amostra['TEMPERATURA DO AR - BULBO SECO, HORARIA (°C)'], errors='coerce')
# Out:
# C:\Users\annea\AppData\Local\Temp\ipykernel_9288\3696780953.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   f_amostra['TEMPERATURA DO AR - BULBO SECO, HORARIA (°C)'] = pd.to_numeric(df_amostra['TEMPERATURA DO AR - BULBO SECO, HORARIA (°C)'], errors='coerce')

# %%
df_amostra['PRECIPITAÇÃO TOTAL, HORÁRIO (mm)'] = pd.to_numeric(df_amostra['PRECIPITAÇÃO TOTAL, HORÁRIO (mm)'], errors='coerce')

# %%
df_amostra['PRECIPITAÇÃO TOTAL, HORÁRIO (mm)'] = pd.to_numeric(df_amostra['PRECIPITAÇÃO TOTAL, HORÁRIO (mm)'], errors='coerce')

# %%
df_amostra.dtypes
# Out:
# Data                                                      object
# Hora UTC                                                  object
# PRECIPITAÇÃO TOTAL, HORÁRIO (mm)                         float64
# PRESSAO ATMOSFERICA AO NIVEL DA ESTACAO, HORARIA (mB)     object
# PRESSÃO ATMOSFERICA MAX.NA HORA ANT. (AUT) (mB)           object
# PRESSÃO ATMOSFERICA MIN. NA HORA ANT. (AUT) (mB)          object
# RADIACAO GLOBAL (Kj/m²)                                   object
# TEMPERATURA DO AR - BULBO SECO, HORARIA (°C)              object
# TEMPERATURA DO PONTO DE ORVALHO (°C)                      object
# TEMPERATURA MÁXIMA NA HORA ANT. (AUT) (°C)                object
# TEMPERATURA MÍNIMA NA HORA ANT. (AUT) (°C)                object
# TEMPERATURA ORVALHO MAX. NA HORA ANT. (AUT) (°C)          object
# TEMPERATURA ORVALHO MIN. NA HORA ANT. (AUT) (°C)          object
# UMIDADE REL. MAX. NA HORA ANT. (AUT) (%)                   int64
# ...

# %%
df_amostra.head(20)
# Out:
#             Data  Hora UTC  PRECIPITAÇÃO TOTAL, HORÁRIO (mm)  \
# 1562  2020/03/06  0200 UTC                               0.0
# 6849  2020/10/12  0900 UTC                               0.0
# 7771  2020/11/19  1900 UTC                               0.0
# 7960  2020/11/27  1600 UTC                               0.0
# 6752  2020/10/08  0800 UTC                               0.0
# 4150  2020/06/21  2200 UTC                               0.0
# 7504  2020/11/08  1600 UTC                               0.0
# 4870  2020/07/21  2200 UTC                               0.0
# 1482  2020/03/02  1800 UTC                               0.8
# 3806  2020/06/07  1400 UTC                               0.0
# 4514  2020/07/07  0200 UTC                               0.0
# 1619  2020/03/08  1100 UTC                               0.0
# 2196  2020/04/01  1200 UTC                               0.0
# 1697  2020/03/11  1700 UTC                               0.0
# ...

# %%
df_amostra.describe()
# Out:
#        UMIDADE REL. MAX. NA HORA ANT. (AUT) (%)  \
# count                                  20.00000
# mean                                   71.15000
# std                                    16.10255
# min                                    40.00000
# 25%                                    62.75000
# 50%                                    74.50000
# 75%                                    82.75000
# max                                    95.00000
#
#        UMIDADE REL. MIN. NA HORA ANT. (AUT) (%)  \
# count                                 20.000000
# mean                                  63.950000
# std                                   17.479236
# min                                   32.000000
# 25%                                   53.500000
# 50%                                   63.000000
# 75%                                   78.250000
# max                                   95.000000
#
#        UMIDADE RELATIVA DO AR, HORARIA (%)  \
# ...

# %%
data = {
    'A': [1, 2, 3],
    'B': [4, 5, 6],
    'C': [7, 8, 9]
}

df_data = pd.DataFrame(data)

# %%
df_data['A+B'] = df_data['A'] * df_data['B']

# %%
df_data.head()
# Out:
#    A  B  C  A+B
# 0  1  4  7    4
# 1  2  5  8   10
# 2  3  6  9   18
