# %%
import pandas as pd

df = pd.read_csv('BSB-2023.CSV', delimiter=';', skiprows=8, encoding='latin1')

# %%
df_amostra = df.sample(n=20)

# %%
df_amostra.head()
# Out:
#             Data  Hora UTC PRECIPITAÇÃO TOTAL, HORÁRIO (mm)  \
# 1252  2023/02/22  0400 UTC                                0
# 6863  2023/10/13  2300 UTC                                0
# 494   2023/01/21  1400 UTC                                0
# 8351  2023/12/14  2300 UTC                                0
# 1104  2023/02/16  0000 UTC                                0
#
#      PRESSAO ATMOSFERICA AO NIVEL DA ESTACAO, HORARIA (mB)  \
# 1252                                              888,8
# 6863                                              887,1
# 494                                               887,1
# 8351                                              884,2
# 1104                                              884,2
#
#      PRESSÃO ATMOSFERICA MAX.NA HORA ANT. (AUT) (mB)  \
# 1252                                           889,3
# 6863                                           887,1
# 494                                            887,5
# 8351                                           884,2
# 1104                                           884,2
#
#      PRESSÃO ATMOSFERICA MIN. NA HORA ANT. (AUT) (mB) RADIACAO GLOBAL (Kj/m²)  \
# 1252                                            888,8                     NaN
# 6863                                            886,5                     NaN
# 494                                             887,1                    3023
# 8351                                            883,8                     NaN
# 1104                                            883,5                     NaN
#
#      TEMPERATURA DO AR - BULBO SECO, HORARIA (°C)  \
# 1252                                         18,9
# 6863                                         20,5
# 494                                          23,5
# 8351                                         26,9
# 1104                                         25,5
#
#      TEMPERATURA DO PONTO DE ORVALHO (°C)  \
# 1252                                 16,6
# 6863                                 17,4
# 494                                  16,5
# 8351                                 11,3
# 1104                                 14,7
#
#      TEMPERATURA MÁXIMA NA HORA ANT. (AUT) (°C)  \
# 1252                                       19,4
# 6863                                       21,3
# 494                                        25,2
# 8351                                       27,8
# 1104                                         26
#
#      TEMPERATURA MÍNIMA NA HORA ANT. (AUT) (°C)  \
# 1252                                       18,9
# 6863                                       20,5
# 494                                        23,5
# 8351                                       26,9
# 1104                                       25,4
#
#      TEMPERATURA ORVALHO MAX. NA HORA ANT. (AUT) (°C)  \
# 1252                                             16,7
# 6863                                             17,7
# 494                                              17,7
# 8351                                             12,3
# 1104                                             15,6
#
#      TEMPERATURA ORVALHO MIN. NA HORA ANT. (AUT) (°C)  \
# 1252                                             16,4
# 6863                                             16,7
# 494                                              15,6
# 8351                                             11,1
# 1104                                               14
#
#       UMIDADE REL. MAX. NA HORA ANT. (AUT) (%)  \
# 1252                                      86.0
# 6863                                      82.0
# 494                                       67.0
# 8351                                      39.0
# 1104                                      54.0
#
#       UMIDADE REL. MIN. NA HORA ANT. (AUT) (%)  \
# 1252                                      83.0
# 6863                                      76.0
# 494                                       58.0
# 8351                                      37.0
# 1104                                      48.0
#
#       UMIDADE RELATIVA DO AR, HORARIA (%)  \
# 1252                                 86.0
# 6863                                 82.0
# 494                                  65.0
# 8351                                 38.0
# 1104                                 51.0
#
#       VENTO, DIREÇÃO HORARIA (gr) (° (gr)) VENTO, RAJADA MAXIMA (m/s)  \
# 1252                                 190.0                        4,1
# 6863                                 173.0                        5,9
# 494                                  335.0                        8,4
# 8351                                 113.0                        5,9
# 1104                                 290.0                        3,9
#
#      VENTO, VELOCIDADE HORARIA (m/s)  Unnamed: 19
# 1252                             1,5          NaN
# 6863                             2,4          NaN
# 494                              4,2          NaN
# 8351                             2,4          NaN
# 1104                             1,6          NaN

# %%
df_amostra = df_amostra[['Data', 'Hora UTC', 'TEMPERATURA DO AR - BULBO SECO, HORARIA (°C)', 'UMIDADE RELATIVA DO AR, HORARIA (%)', 'PRECIPITAÇÃO TOTAL, HORÁRIO (mm)']]

# %%
df_amostra
# Out:
#             Data  Hora UTC TEMPERATURA DO AR - BULBO SECO, HORARIA (°C)  \
# 1252  2023/02/22  0400 UTC                                         18,9
# 6863  2023/10/13  2300 UTC                                         20,5
# 494   2023/01/21  1400 UTC                                         23,5
# 8351  2023/12/14  2300 UTC                                         26,9
# 1104  2023/02/16  0000 UTC                                         25,5
# 6561  2023/10/01  0900 UTC                                         21,4
# 5516  2023/08/18  2000 UTC                                         27,3
# 6058  2023/09/10  1000 UTC                                         19,5
# 258   2023/01/11  1800 UTC                                         18,7
# 1342  2023/02/25  2200 UTC                                         24,9
# 1545  2023/03/06  0900 UTC                                         18,6
# 6625  2023/10/04  0100 UTC                                         19,2
# 6042  2023/09/09  1800 UTC                                         28,3
# 4915  2023/07/24  1900 UTC                                         24,4
# 6613  2023/10/03  1300 UTC                                           25
# 8122  2023/12/05  1000 UTC                                         21,3
# 1697  2023/03/12  1700 UTC                                         26,5
# 1289  2023/02/23  1700 UTC                                         23,5
# 3225  2023/05/15  0900 UTC                                           14
# 4328  2023/06/30  0800 UTC                                         14,9
#
#       UMIDADE RELATIVA DO AR, HORARIA (%) PRECIPITAÇÃO TOTAL, HORÁRIO (mm)
# 1252                                 86.0                                0
# 6863                                 82.0                                0
# 494                                  65.0                                0
# 8351                                 38.0                                0
# 1104                                 51.0                                0
# 6561                                 73.0                                0
# 5516                                 27.0                                0
# 6058                                 44.0                                0
# 258                                  91.0                             17,6
# 1342                                 62.0                                0
# 1545                                 86.0                                0
# 6625                                 86.0                                0
# 6042                                 28.0                                0
# 4915                                 46.0                                0
# 6613                                 68.0                                0
# 8122                                 85.0                                0
# 1697                                 55.0                                0
# 1289                                 74.0                                0
# 3225                                 84.0                                0
# 4328                                 74.0                                0

# %%
df_amostra['TEMPERATURA DO AR - BULBO SECO, HORARIA (°C)'] = df_amostra['TEMPERATURA DO AR - BULBO SECO, HORARIA (°C)'].replace(',', '.', regex=True)

# %%
df_amostra['PRECIPITAÇÃO TOTAL, HORÁRIO (mm)'] = df_amostra['PRECIPITAÇÃO TOTAL, HORÁRIO (mm)'].replace(',', '.', regex=True)

# %%
df_amostra.head()
# Out:
#             Data  Hora UTC TEMPERATURA DO AR - BULBO SECO, HORARIA (°C)  \
# 1252  2023/02/22  0400 UTC                                         18.9
# 6863  2023/10/13  2300 UTC                                         20.5
# 494   2023/01/21  1400 UTC                                         23.5
# 8351  2023/12/14  2300 UTC                                         26.9
# 1104  2023/02/16  0000 UTC                                         25.5
#
#       UMIDADE RELATIVA DO AR, HORARIA (%) PRECIPITAÇÃO TOTAL, HORÁRIO (mm)
# 1252                                 86.0                                0
# 6863                                 82.0                                0
# 494                                  65.0                                0
# 8351                                 38.0                                0
# 1104                                 51.0                                0

# %%
df_amostra.dtypes
# Out:
# Data                                             object
# Hora UTC                                         object
# TEMPERATURA DO AR - BULBO SECO, HORARIA (°C)     object
# UMIDADE RELATIVA DO AR, HORARIA (%)             float64
# PRECIPITAÇÃO TOTAL, HORÁRIO (mm)                 object
# dtype: object

# %%
df_amostra['TEMPERATURA DO AR - BULBO SECO, HORARIA (°C)'] = pd.to_numeric(df_amostra['TEMPERATURA DO AR - BULBO SECO, HORARIA (°C)'], errors='coerce')

# %%
df_amostra['PRECIPITAÇÃO TOTAL, HORÁRIO (mm)'] = pd.to_numeric(df_amostra['PRECIPITAÇÃO TOTAL, HORÁRIO (mm)'], errors='coerce')

# %%
df_amostra['PRECIPITAÇÃO TOTAL, HORÁRIO (mm)'] = pd.to_numeric(df_amostra['PRECIPITAÇÃO TOTAL, HORÁRIO (mm)'], errors='coerce')

# %%
df_amostra.dtypes
# Out:
# Data                                             object
# Hora UTC                                         object
# TEMPERATURA DO AR - BULBO SECO, HORARIA (°C)    float64
# UMIDADE RELATIVA DO AR, HORARIA (%)             float64
# PRECIPITAÇÃO TOTAL, HORÁRIO (mm)                float64
# dtype: object

# %%
df_amostra.head(20)
# Out:
#             Data  Hora UTC  TEMPERATURA DO AR - BULBO SECO, HORARIA (°C)  \
# 1252  2023/02/22  0400 UTC                                          18.9
# 6863  2023/10/13  2300 UTC                                          20.5
# 494   2023/01/21  1400 UTC                                          23.5
# 8351  2023/12/14  2300 UTC                                          26.9
# 1104  2023/02/16  0000 UTC                                          25.5
# 6561  2023/10/01  0900 UTC                                          21.4
# 5516  2023/08/18  2000 UTC                                          27.3
# 6058  2023/09/10  1000 UTC                                          19.5
# 258   2023/01/11  1800 UTC                                          18.7
# 1342  2023/02/25  2200 UTC                                          24.9
# 1545  2023/03/06  0900 UTC                                          18.6
# 6625  2023/10/04  0100 UTC                                          19.2
# 6042  2023/09/09  1800 UTC                                          28.3
# 4915  2023/07/24  1900 UTC                                          24.4
# 6613  2023/10/03  1300 UTC                                          25.0
# 8122  2023/12/05  1000 UTC                                          21.3
# 1697  2023/03/12  1700 UTC                                          26.5
# 1289  2023/02/23  1700 UTC                                          23.5
# 3225  2023/05/15  0900 UTC                                          14.0
# 4328  2023/06/30  0800 UTC                                          14.9
#
#       UMIDADE RELATIVA DO AR, HORARIA (%)  PRECIPITAÇÃO TOTAL, HORÁRIO (mm)
# 1252                                 86.0                               0.0
# 6863                                 82.0                               0.0
# 494                                  65.0                               0.0
# 8351                                 38.0                               0.0
# 1104                                 51.0                               0.0
# 6561                                 73.0                               0.0
# 5516                                 27.0                               0.0
# 6058                                 44.0                               0.0
# 258                                  91.0                              17.6
# 1342                                 62.0                               0.0
# 1545                                 86.0                               0.0
# 6625                                 86.0                               0.0
# 6042                                 28.0                               0.0
# 4915                                 46.0                               0.0
# 6613                                 68.0                               0.0
# 8122                                 85.0                               0.0
# 1697                                 55.0                               0.0
# 1289                                 74.0                               0.0
# 3225                                 84.0                               0.0
# 4328                                 74.0                               0.0

# %%
df_amostra.describe()
# Out:
#        TEMPERATURA DO AR - BULBO SECO, HORARIA (°C)  \
# count                                     20.000000
# mean                                      22.140000
# std                                        4.073199
# min                                       14.000000
# 25%                                       19.125000
# 50%                                       22.450000
# 75%                                       25.125000
# max                                       28.300000
#
#        UMIDADE RELATIVA DO AR, HORARIA (%)  PRECIPITAÇÃO TOTAL, HORÁRIO (mm)
# count                            20.000000                          20.00000
# mean                             65.250000                           0.88000
# std                              20.431851                           3.93548
# min                              27.000000                           0.00000
# 25%                              49.750000                           0.00000
# 50%                              70.500000                           0.00000
# 75%                              84.250000                           0.00000
# max                              91.000000                          17.60000

# %%
data = {
    'A': [1, 2, 3],
    'B': [4, 5, 6],
    'C': [7, 8, 9]
}

df_data = pd.DataFrame(data)

# %%
df_data['A+B'] = df_data['A'] * df_data['B']

# %%
df_data.head()
# Out:
#    A  B  C  A+B
# 0  1  4  7    4
# 1  2  5  8   10
# 2  3  6  9   18
