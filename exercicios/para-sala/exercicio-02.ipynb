# %%
import pandas as pd

df = pd.read_csv('BSB-2023.CSV', delimiter=';', skiprows=8, encoding='latin1')

# %%
df_amostra = df.sample(n=20)

# %%
df_amostra.head()
# Out:
#             Data  Hora UTC PRECIPITAÇÃO TOTAL, HORÁRIO (mm)  \
# 6219  2023/09/17  0300 UTC                                0
# 6478  2023/09/27  2200 UTC                                0
# 1333  2023/02/25  1300 UTC                                0
# 4840  2023/07/21  1600 UTC                                0
# 2655  2023/04/21  1500 UTC                                0
#
#      PRESSAO ATMOSFERICA AO NIVEL DA ESTACAO, HORARIA (mB)  \
# 6219                                              888,9
# 6478                                              884,3
# 1333                                              888,5
# 4840                                              894,1
# 2655                                                887
#
#      PRESSÃO ATMOSFERICA MAX.NA HORA ANT. (AUT) (mB)  \
# 6219                                           889,4
# 6478                                           884,3
# 1333                                           888,6
# 4840                                           894,8
# 2655                                             888
#
#      PRESSÃO ATMOSFERICA MIN. NA HORA ANT. (AUT) (mB) RADIACAO GLOBAL (Kj/m²)  \
# 6219                                            888,9                     NaN
# 6478                                            883,7                     NaN
# 1333                                            888,3                  2591,4
# 4840                                              894                  2717,8
# 2655                                              887                  2822,1
#
#      TEMPERATURA DO AR - BULBO SECO, HORARIA (°C)  \
# 6219                                           23
# 6478                                         23,7
# 1333                                         25,8
# 4840                                         22,5
# 2655                                         22,9
#
#      TEMPERATURA DO PONTO DE ORVALHO (°C)  \
# 6219                                 13,4
# 6478                                 17,3
# 1333                                   18
# 4840                                 11,2
# 2655                                 15,7
#
#      TEMPERATURA MÁXIMA NA HORA ANT. (AUT) (°C)  \
# 6219                                       23,3
# 6478                                       25,1
# 1333                                       25,9
# 4840                                       23,5
# 2655                                       23,3
#
#      TEMPERATURA MÍNIMA NA HORA ANT. (AUT) (°C)  \
# 6219                                       20,7
# 6478                                       23,7
# 1333                                       24,5
# 4840                                       21,4
# 2655                                       21,5
#
#      TEMPERATURA ORVALHO MAX. NA HORA ANT. (AUT) (°C)  \
# 6219                                             14,4
# 6478                                             17,8
# 1333                                             18,4
# 4840                                             12,4
# 2655                                             16,1
#
#      TEMPERATURA ORVALHO MIN. NA HORA ANT. (AUT) (°C)  \
# 6219                                             13,4
# 6478                                             17,3
# 1333                                             17,2
# 4840                                             11,2
# 2655                                             14,4
#
#       UMIDADE REL. MAX. NA HORA ANT. (AUT) (%)  \
# 6219                                      66.0
# 6478                                      67.0
# 1333                                      67.0
# 4840                                      55.0
# 2655                                      66.0
#
#       UMIDADE REL. MIN. NA HORA ANT. (AUT) (%)  \
# 6219                                      54.0
# 6478                                      63.0
# 1333                                      62.0
# 4840                                      47.0
# 2655                                      61.0
#
#       UMIDADE RELATIVA DO AR, HORARIA (%)  \
# 6219                                 55.0
# 6478                                 67.0
# 1333                                 62.0
# 4840                                 49.0
# 2655                                 64.0
#
#       VENTO, DIREÇÃO HORARIA (gr) (° (gr)) VENTO, RAJADA MAXIMA (m/s)  \
# 6219                                  77.0                          5
# 6478                                 296.0                        6,1
# 1333                                  67.0                        6,7
# 4840                                  94.0                       10,8
# 2655                                  91.0                        6,9
#
#      VENTO, VELOCIDADE HORARIA (m/s)  Unnamed: 19
# 6219                             2,6          NaN
# 6478                             1,8          NaN
# 1333                             3,3          NaN
# 4840                             6,1          NaN
# 2655                             3,6          NaN

# %%
df_amostra = df_amostra[['Data', 'Hora UTC', 'TEMPERATURA DO AR - BULBO SECO, HORARIA (°C)', 'UMIDADE RELATIVA DO AR, HORARIA (%)', 'PRECIPITAÇÃO TOTAL, HORÁRIO (mm)']]

# %%
df_amostra
# Out:
#             Data  Hora UTC TEMPERATURA DO AR - BULBO SECO, HORARIA (°C)  \
# 6219  2023/09/17  0300 UTC                                           23
# 6478  2023/09/27  2200 UTC                                         23,7
# 1333  2023/02/25  1300 UTC                                         25,8
# 4840  2023/07/21  1600 UTC                                         22,5
# 2655  2023/04/21  1500 UTC                                         22,9
# 4611  2023/07/12  0300 UTC                                           17
# 5922  2023/09/04  1800 UTC                                           31
# 3366  2023/05/21  0600 UTC                                         15,5
# 3823  2023/06/09  0700 UTC                                         13,1
# 793   2023/02/03  0100 UTC                                         21,4
# 8701  2023/12/29  1300 UTC                                         28,5
# 5786  2023/08/30  0200 UTC                                         19,9
# 7924  2023/11/27  0400 UTC                                         21,6
# 4459  2023/07/05  1900 UTC                                         22,4
# 5062  2023/07/30  2200 UTC                                         23,4
# 1740  2023/03/14  1200 UTC                                           21
# 7767  2023/11/20  1500 UTC                                         22,2
# 2873  2023/04/30  1700 UTC                                         16,5
# 1294  2023/02/23  2200 UTC                                         20,8
# 2881  2023/05/01  0100 UTC                                         18,5
#
#       UMIDADE RELATIVA DO AR, HORARIA (%) PRECIPITAÇÃO TOTAL, HORÁRIO (mm)
# 6219                                 55.0                                0
# 6478                                 67.0                                0
# 1333                                 62.0                                0
# 4840                                 49.0                                0
# 2655                                 64.0                                0
# 4611                                 67.0                                0
# 5922                                 31.0                                0
# 3366                                 66.0                                0
# 3823                                 86.0                                0
# 793                                  71.0                                0
# 8701                                 56.0                                0
# 5786                                 82.0                                7
# 7924                                 83.0                                0
# 4459                                 35.0                                0
# 5062                                 39.0                                0
# 1740                                 79.0                                0
# 7767                                 78.0                                0
# 2873                                 92.0                             21,6
# 1294                                 78.0                                0
# 2881                                 87.0                                0

# %%
df_amostra['TEMPERATURA DO AR - BULBO SECO, HORARIA (°C)'] = df_amostra['TEMPERATURA DO AR - BULBO SECO, HORARIA (°C)'].replace(',', '.', regex=True)

# %%
df_amostra['PRECIPITAÇÃO TOTAL, HORÁRIO (mm)'] = df_amostra['PRECIPITAÇÃO TOTAL, HORÁRIO (mm)'].replace(',', '.', regex=True)

# %%
df_amostra.head()
# Out:
#             Data  Hora UTC TEMPERATURA DO AR - BULBO SECO, HORARIA (°C)  \
# 6219  2023/09/17  0300 UTC                                           23
# 6478  2023/09/27  2200 UTC                                         23.7
# 1333  2023/02/25  1300 UTC                                         25.8
# 4840  2023/07/21  1600 UTC                                         22.5
# 2655  2023/04/21  1500 UTC                                         22.9
#
#       UMIDADE RELATIVA DO AR, HORARIA (%) PRECIPITAÇÃO TOTAL, HORÁRIO (mm)
# 6219                                 55.0                                0
# 6478                                 67.0                                0
# 1333                                 62.0                                0
# 4840                                 49.0                                0
# 2655                                 64.0                                0

# %%
df_amostra.dtypes
# Out:
# Data                                             object
# Hora UTC                                         object
# TEMPERATURA DO AR - BULBO SECO, HORARIA (°C)     object
# UMIDADE RELATIVA DO AR, HORARIA (%)             float64
# PRECIPITAÇÃO TOTAL, HORÁRIO (mm)                 object
# dtype: object

# %%
df_amostra['TEMPERATURA DO AR - BULBO SECO, HORARIA (°C)'] = pd.to_numeric(df_amostra['TEMPERATURA DO AR - BULBO SECO, HORARIA (°C)'], errors='coerce')

# %%
df_amostra['PRECIPITAÇÃO TOTAL, HORÁRIO (mm)'] = pd.to_numeric(df_amostra['PRECIPITAÇÃO TOTAL, HORÁRIO (mm)'], errors='coerce')

# %%
df_amostra['PRECIPITAÇÃO TOTAL, HORÁRIO (mm)'] = pd.to_numeric(df_amostra['PRECIPITAÇÃO TOTAL, HORÁRIO (mm)'], errors='coerce')

# %%
df_amostra.dtypes
# Out:
# Data                                             object
# Hora UTC                                         object
# TEMPERATURA DO AR - BULBO SECO, HORARIA (°C)    float64
# UMIDADE RELATIVA DO AR, HORARIA (%)             float64
# PRECIPITAÇÃO TOTAL, HORÁRIO (mm)                float64
# dtype: object

# %%
df_amostra.head(20)
# Out:
#             Data  Hora UTC  TEMPERATURA DO AR - BULBO SECO, HORARIA (°C)  \
# 6219  2023/09/17  0300 UTC                                          23.0
# 6478  2023/09/27  2200 UTC                                          23.7
# 1333  2023/02/25  1300 UTC                                          25.8
# 4840  2023/07/21  1600 UTC                                          22.5
# 2655  2023/04/21  1500 UTC                                          22.9
# 4611  2023/07/12  0300 UTC                                          17.0
# 5922  2023/09/04  1800 UTC                                          31.0
# 3366  2023/05/21  0600 UTC                                          15.5
# 3823  2023/06/09  0700 UTC                                          13.1
# 793   2023/02/03  0100 UTC                                          21.4
# 8701  2023/12/29  1300 UTC                                          28.5
# 5786  2023/08/30  0200 UTC                                          19.9
# 7924  2023/11/27  0400 UTC                                          21.6
# 4459  2023/07/05  1900 UTC                                          22.4
# 5062  2023/07/30  2200 UTC                                          23.4
# 1740  2023/03/14  1200 UTC                                          21.0
# 7767  2023/11/20  1500 UTC                                          22.2
# 2873  2023/04/30  1700 UTC                                          16.5
# 1294  2023/02/23  2200 UTC                                          20.8
# 2881  2023/05/01  0100 UTC                                          18.5
#
#       UMIDADE RELATIVA DO AR, HORARIA (%)  PRECIPITAÇÃO TOTAL, HORÁRIO (mm)
# 6219                                 55.0                               0.0
# 6478                                 67.0                               0.0
# 1333                                 62.0                               0.0
# 4840                                 49.0                               0.0
# 2655                                 64.0                               0.0
# 4611                                 67.0                               0.0
# 5922                                 31.0                               0.0
# 3366                                 66.0                               0.0
# 3823                                 86.0                               0.0
# 793                                  71.0                               0.0
# 8701                                 56.0                               0.0
# 5786                                 82.0                               7.0
# 7924                                 83.0                               0.0
# 4459                                 35.0                               0.0
# 5062                                 39.0                               0.0
# 1740                                 79.0                               0.0
# 7767                                 78.0                               0.0
# 2873                                 92.0                              21.6
# 1294                                 78.0                               0.0
# 2881                                 87.0                               0.0

# %%
df_amostra.describe()
# Out:
#        TEMPERATURA DO AR - BULBO SECO, HORARIA (°C)  \
# count                                     20.000000
# mean                                      21.535000
# std                                        4.210298
# min                                       13.100000
# 25%                                       19.550000
# 50%                                       21.900000
# 75%                                       23.100000
# max                                       31.000000
#
#        UMIDADE RELATIVA DO AR, HORARIA (%)  PRECIPITAÇÃO TOTAL, HORÁRIO (mm)
# count                            20.000000                         20.000000
# mean                             66.350000                          1.430000
# std                              17.753502                          4.998221
# min                              31.000000                          0.000000
# 25%                              55.750000                          0.000000
# 50%                              67.000000                          0.000000
# 75%                              79.750000                          0.000000
# max                              92.000000                         21.600000

# %%
data = {
    'A': [1, 2, 3],
    'B': [4, 5, 6],
    'C': [7, 8, 9]
}

df_data = pd.DataFrame(data)

# %%
df_data['A+B'] = df_data['A'] * df_data['B']

# %%
df_data.head()
# Out:
#    A  B  C  A+B
# 0  1  4  7    4
# 1  2  5  8   10
# 2  3  6  9   18
