# %%
import pandas as pd
df = pd.read_csv('exercicio-segunda.CSV', delimiter=';', skiprows=8, encoding='latin1')

# %%
df.head()
# Out:
#          Data  Hora UTC PRECIPITAÇÃO TOTAL, HORÁRIO (mm)  \
# 0  2023/01/01  0000 UTC                                0
# 1  2023/01/01  0100 UTC                                0
# 2  2023/01/01  0200 UTC                                0
# 3  2023/01/01  0300 UTC                                0
# 4  2023/01/01  0400 UTC                                0
#
#   PRESSAO ATMOSFERICA AO NIVEL DA ESTACAO, HORARIA (mB)  \
# 0                                              887,7
# 1                                              888,1
# 2                                              887,8
# 3                                              887,8
# 4                                              887,6
#
#   PRESSÃO ATMOSFERICA MAX.NA HORA ANT. (AUT) (mB)  \
# 0                                           887,7
# 1                                           888,1
# 2                                           888,1
# 3                                           887,9
# ...

# %%
df.head(10)
# Out:
#          Data  Hora UTC PRECIPITAÇÃO TOTAL, HORÁRIO (mm)  \
# 0  2023/01/01  0000 UTC                                0
# 1  2023/01/01  0100 UTC                                0
# 2  2023/01/01  0200 UTC                                0
# 3  2023/01/01  0300 UTC                                0
# 4  2023/01/01  0400 UTC                                0
# 5  2023/01/01  0500 UTC                                0
# 6  2023/01/01  0600 UTC                                0
# 7  2023/01/01  0700 UTC                                0
# 8  2023/01/01  0800 UTC                                0
# 9  2023/01/01  0900 UTC                                0
#
#   PRESSAO ATMOSFERICA AO NIVEL DA ESTACAO, HORARIA (mB)  \
# 0                                              887,7
# 1                                              888,1
# 2                                              887,8
# 3                                              887,8
# 4                                              887,6
# ...

# %%
df_amostra = df.sample(n=20)

# %%
df.head()
# Out:
#          Data  Hora UTC PRECIPITAÇÃO TOTAL, HORÁRIO (mm)  \
# 0  2023/01/01  0000 UTC                                0
# 1  2023/01/01  0100 UTC                                0
# 2  2023/01/01  0200 UTC                                0
# 3  2023/01/01  0300 UTC                                0
# 4  2023/01/01  0400 UTC                                0
#
#   PRESSAO ATMOSFERICA AO NIVEL DA ESTACAO, HORARIA (mB)  \
# 0                                              887,7
# 1                                              888,1
# 2                                              887,8
# 3                                              887,8
# 4                                              887,6
#
#   PRESSÃO ATMOSFERICA MAX.NA HORA ANT. (AUT) (mB)  \
# 0                                           887,7
# 1                                           888,1
# 2                                           888,1
# 3                                           887,9
# ...
