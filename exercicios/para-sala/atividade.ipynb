# %%
import pandas as pd

df = pd.read_csv('brasilia.csv', delimiter=';', skiprows=8, encoding='latin1')

# %%
df.head()
# Out:
#          Data  Hora UTC PRECIPITAÇÃO TOTAL, HORÁRIO (mm)  \
# 0  2020/01/01  0000 UTC                                0
# 1  2020/01/01  0100 UTC                                0
# 2  2020/01/01  0200 UTC                                0
# 3  2020/01/01  0300 UTC                                0
# 4  2020/01/01  0400 UTC                                0
#
#   PRESSAO ATMOSFERICA AO NIVEL DA ESTACAO, HORARIA (mB)  \
# 0                                              884,1
# 1                                                885
# 2                                              885,5
# 3                                              885,3
# 4                                              885,2
#
#   PRESSÃO ATMOSFERICA MAX.NA HORA ANT. (AUT) (mB)  \
# 0                                           884,2
# 1                                             885
# 2                                           885,5
# 3                                           885,5
# ...

# %%
df_reduzido = df[['Data', 'PRESSAO ATMOSFERICA AO NIVEL DA ESTACAO, HORARIA (mB)', 'VENTO, VELOCIDADE HORARIA (m/s)', 'TEMPERATURA DO PONTO DE ORVALHO (°C)', 'RADIACAO GLOBAL (Kj/m²)']]
df_reduzido.head()
# Out:
#          Data PRESSAO ATMOSFERICA AO NIVEL DA ESTACAO, HORARIA (mB)  \
# 0  2020/01/01                                              884,1
# 1  2020/01/01                                                885
# 2  2020/01/01                                              885,5
# 3  2020/01/01                                              885,3
# 4  2020/01/01                                              885,2
#
#   VENTO, VELOCIDADE HORARIA (m/s) TEMPERATURA DO PONTO DE ORVALHO (°C)  \
# 0                              ,8                                 18,1
# 1                              ,3                                 18,1
# 2                             1,1                                 18,8
# 3                               1                                 17,9
# 4                             1,4                                 17,3
#
#   RADIACAO GLOBAL (Kj/m²)
# 0                     NaN
# 1                     NaN
# 2                     NaN
# 3                     NaN
# ...

# %%
remover = df_reduzido.dropna(axis=0, how='all')
remover.head()
# Out:
#          Data PRESSAO ATMOSFERICA AO NIVEL DA ESTACAO, HORARIA (mB)  \
# 0  2020/01/01                                              884,1
# 1  2020/01/01                                                885
# 2  2020/01/01                                              885,5
# 3  2020/01/01                                              885,3
# 4  2020/01/01                                              885,2
#
#   VENTO, VELOCIDADE HORARIA (m/s) TEMPERATURA DO PONTO DE ORVALHO (°C)  \
# 0                              ,8                                 18,1
# 1                              ,3                                 18,1
# 2                             1,1                                 18,8
# 3                               1                                 17,9
# 4                             1,4                                 17,3
#
#   RADIACAO GLOBAL (Kj/m²)
# 0                     NaN
# 1                     NaN
# 2                     NaN
# 3                     NaN
# ...

# %%
df_reduzido.isnull()
isnull.head
# Out:
#        Data  PRESSAO ATMOSFERICA AO NIVEL DA ESTACAO, HORARIA (mB)  \
# 0     False                                              False
# 1     False                                              False
# 2     False                                              False
# 3     False                                              False
# 4     False                                              False
# ...     ...                                                ...
# 8779  False                                              False
# 8780  False                                              False
# 8781  False                                              False
# 8782  False                                              False
# 8783  False                                              False
#
#       VENTO, VELOCIDADE HORARIA (m/s)  TEMPERATURA DO PONTO DE ORVALHO (°C)  \
# 0                               False                                 False
# ...
