# %%
import pandas as pd

df = pd.read_csv('INMET_CO_GO_A014_GOIAS_01-01-2023_A_31-12-2023.csv', delimiter=';', skiprows=8, encoding='latin1')

# %%
df.head(20)
# Out:
#           Data  Hora UTC PRECIPITAÇÃO TOTAL, HORÁRIO (mm)  \
# 0   2023/01/01  0000 UTC                                0
# 1   2023/01/01  0100 UTC                                0
# 2   2023/01/01  0200 UTC                                0
# 3   2023/01/01  0300 UTC                                0
# 4   2023/01/01  0400 UTC                                0
# 5   2023/01/01  0500 UTC                                0
# 6   2023/01/01  0600 UTC                                0
# 7   2023/01/01  0700 UTC                                0
# 8   2023/01/01  0800 UTC                                0
# 9   2023/01/01  0900 UTC                                0
# 10  2023/01/01  1000 UTC                                0
# 11  2023/01/01  1100 UTC                                0
# 12  2023/01/01  1200 UTC                                0
# 13  2023/01/01  1300 UTC                                0
# 14  2023/01/01  1400 UTC                                0
# ...

# %%
df.tail()
# Out:
#             Data  Hora UTC PRECIPITAÇÃO TOTAL, HORÁRIO (mm)  \
# 8755  2023/12/31  1900 UTC                              NaN
# 8756  2023/12/31  2000 UTC                              NaN
# 8757  2023/12/31  2100 UTC                              NaN
# 8758  2023/12/31  2200 UTC                              NaN
# 8759  2023/12/31  2300 UTC                              NaN
#
#      PRESSAO ATMOSFERICA AO NIVEL DA ESTACAO, HORARIA (mB)  \
# 8755                                                NaN
# 8756                                                NaN
# 8757                                                NaN
# 8758                                                NaN
# 8759                                                NaN
#
#      PRESSÃO ATMOSFERICA MAX.NA HORA ANT. (AUT) (mB)  \
# 8755                                             NaN
# 8756                                             NaN
# 8757                                             NaN
# ...

# %%
df.shape
# Out:
# (8760, 20)

# %%
df.describe()
# Out:
#        UMIDADE REL. MAX. NA HORA ANT. (AUT) (%)  \
# count                               7456.000000
# mean                                  63.126475
# std                                   21.313343
# min                                   13.000000
# 25%                                   47.000000
# 50%                                   65.000000
# 75%                                   81.000000
# max                                   96.000000
#
#        UMIDADE REL. MIN. NA HORA ANT. (AUT) (%)  \
# count                               7456.000000
# mean                                  57.015021
# std                                   22.038739
# min                                    9.000000
# 25%                                   39.000000
# 50%                                   58.000000
# 75%                                   75.000000
# max                                   96.000000
#
#        UMIDADE RELATIVA DO AR, HORARIA (%)  \
# ...

# %%
df.dtypes
# Out:
# Data                                                      object
# Hora UTC                                                  object
# PRECIPITAÇÃO TOTAL, HORÁRIO (mm)                          object
# PRESSAO ATMOSFERICA AO NIVEL DA ESTACAO, HORARIA (mB)     object
# PRESSÃO ATMOSFERICA MAX.NA HORA ANT. (AUT) (mB)           object
# PRESSÃO ATMOSFERICA MIN. NA HORA ANT. (AUT) (mB)          object
# RADIACAO GLOBAL (Kj/m²)                                   object
# TEMPERATURA DO AR - BULBO SECO, HORARIA (°C)              object
# TEMPERATURA DO PONTO DE ORVALHO (°C)                      object
# TEMPERATURA MÁXIMA NA HORA ANT. (AUT) (°C)                object
# TEMPERATURA MÍNIMA NA HORA ANT. (AUT) (°C)                object
# TEMPERATURA ORVALHO MAX. NA HORA ANT. (AUT) (°C)          object
# TEMPERATURA ORVALHO MIN. NA HORA ANT. (AUT) (°C)          object
# UMIDADE REL. MAX. NA HORA ANT. (AUT) (%)                 float64
# ...

# %%
df.sample()
# Out:
#             Data  Hora UTC PRECIPITAÇÃO TOTAL, HORÁRIO (mm)  \
# 1019  2023/02/12  1100 UTC                                0
#
#      PRESSAO ATMOSFERICA AO NIVEL DA ESTACAO, HORARIA (mB)  \
# 1019                                              953,9
#
#      PRESSÃO ATMOSFERICA MAX.NA HORA ANT. (AUT) (mB)  \
# 1019                                           953,9
#
#      PRESSÃO ATMOSFERICA MIN. NA HORA ANT. (AUT) (mB) RADIACAO GLOBAL (Kj/m²)  \
# 1019                                            953,3                    1171
#
#      TEMPERATURA DO AR - BULBO SECO, HORARIA (°C)  \
# 1019                                         27,1
#
#      TEMPERATURA DO PONTO DE ORVALHO (°C)  \
# 1019                                 22,1
#
#      TEMPERATURA MÁXIMA NA HORA ANT. (AUT) (°C)  \
# 1019                                       27,1
#
#      TEMPERATURA MÍNIMA NA HORA ANT. (AUT) (°C)  \
# 1019                                       23,1
#
# ...

# %%
df.sample(5)
# Out:
#             Data  Hora UTC PRECIPITAÇÃO TOTAL, HORÁRIO (mm)  \
# 8593  2023/12/25  0100 UTC                              NaN
# 199   2023/01/09  0700 UTC                                0
# 3231  2023/05/15  1500 UTC                                0
# 6945  2023/10/17  0900 UTC                                0
# 2514  2023/04/15  1800 UTC                                0
#
#      PRESSAO ATMOSFERICA AO NIVEL DA ESTACAO, HORARIA (mB)  \
# 8593                                                NaN
# 199                                                 954
# 3231                                              958,3
# 6945                                              954,8
# 2514                                              952,8
#
#      PRESSÃO ATMOSFERICA MAX.NA HORA ANT. (AUT) (mB)  \
# 8593                                             NaN
# 199                                            954,2
# 3231                                           959,1
# ...

# %%
df_reduzido = df[['Data', 'Hora UTC', 'PRECIPITAÇÃO TOTAL, HORÁRIO (mm)']]

# %%
df_reduzido.head ()
# Out:
#          Data  Hora UTC PRECIPITAÇÃO TOTAL, HORÁRIO (mm)
# 0  2023/01/01  0000 UTC                                0
# 1  2023/01/01  0100 UTC                                0
# 2  2023/01/01  0200 UTC                                0
# 3  2023/01/01  0300 UTC                                0
# 4  2023/01/01  0400 UTC                                0

# %%
coluna_data = df['Data']

# %%
coluna_data.head()
# Out:
# 0    2023/01/01
# 1    2023/01/01
# 2    2023/01/01
# 3    2023/01/01
# 4    2023/01/01
# Name: Data, dtype: object

# %%
coluna_data.min()
# Out:
# '2023/01/01'

# %%
coluna_temperatura_maxima = df['TEMPERATURA MÁXIMA NA HORA ANT. (AUT) (°C)']

# %%
coluna_temperatura_maxima.min()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[30], line 1
# ----> 1 coluna_temperatura_maxima.min()
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\pandas\core\series.py:6507, in Series.min(self, axis, skipna, numeric_only, **kwargs)
#    6499 @doc(make_doc("min", ndim=1))
#    6500 def min(
#    6501     self,
#    (...)
#    6505     **kwargs,
#    6506 ):
# -> 6507     return NDFrame.min(self, axis, skipna, numeric_only, **kwargs)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\pandas\core\generic.py:12388, in NDFrame.min(self, axis, skipna, numeric_only, **kwargs)
#   12381 def min(
#   12382     self,
#   12383     axis: Axis | None = 0,
#    (...)
#   12386     **kwargs,
#   12387 ):
# ...

# %%
coluna_temperatura_maxima.dtype()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[31], line 1
# ----> 1 coluna_temperatura_maxima.dtype()
#
# TypeError: 'numpy.dtypes.ObjectDType' object is not callable

# %%
coluna_temperatura_maxima.min()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[32], line 1
# ----> 1 coluna_temperatura_maxima.min()
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\pandas\core\series.py:6507, in Series.min(self, axis, skipna, numeric_only, **kwargs)
#    6499 @doc(make_doc("min", ndim=1))
#    6500 def min(
#    6501     self,
#    (...)
#    6505     **kwargs,
#    6506 ):
# -> 6507     return NDFrame.min(self, axis, skipna, numeric_only, **kwargs)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\pandas\core\generic.py:12388, in NDFrame.min(self, axis, skipna, numeric_only, **kwargs)
#   12381 def min(
#   12382     self,
#   12383     axis: Axis | None = 0,
#    (...)
#   12386     **kwargs,
#   12387 ):
# ...

# %%
coluna_temperatura_ponto_de_orvalho = df['TEMPERATURA DO PONTO DE ORVALHO (°C)']

# %%
coluna_temperatura_ponto_de_orvalho.min()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[35], line 1
# ----> 1 coluna_temperatura_ponto_de_orvalho.min()
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\pandas\core\series.py:6507, in Series.min(self, axis, skipna, numeric_only, **kwargs)
#    6499 @doc(make_doc("min", ndim=1))
#    6500 def min(
#    6501     self,
#    (...)
#    6505     **kwargs,
#    6506 ):
# -> 6507     return NDFrame.min(self, axis, skipna, numeric_only, **kwargs)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\pandas\core\generic.py:12388, in NDFrame.min(self, axis, skipna, numeric_only, **kwargs)
#   12381 def min(
#   12382     self,
#   12383     axis: Axis | None = 0,
#    (...)
#   12386     **kwargs,
# ...

# %%
coluna_temperatura_ponto_de_orvalho = df['UMIDADE REL. MAX. NA HORA ANT. (AUT) (%)']

# %%
coluna_relativa_max.min()
# Out:
# np.float64(13.0)

# %%
coluna_relativa_max.max()
# Out:
# np.float64(96.0)

# %%
#coluna_relativa_max.max()

coluna_relativa_max.mean

#coluna_relativa_maxima.sum
# Out:
# <bound method Series.mean of 0       94.0
# 1       95.0
# 2       94.0
# 3       95.0
# 4       94.0
#         ...
# 8755     NaN
# 8756     NaN
# 8757     NaN
# 8758     NaN
# 8759     NaN
# Name: UMIDADE REL. MAX. NA HORA ANT. (AUT) (%), Length: 8760, dtype: float64>

# %%
coluna_relativa_maxima = pd.to_numeric(df('UMIDADE REL. MAX. NA HORA ANT. (AUT) (%)'), errors='coerce')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[46], line 1
# ----> 1 coluna_relativa_maxima = pd.to_numeric(df('UMIDADE REL. MAX. NA HORA ANT. (AUT) (%)'), errors='coerce')
#
# TypeError: 'DataFrame' object is not callable

# %%
df.isnull()
# Out:
#        Data  Hora UTC  PRECIPITAÇÃO TOTAL, HORÁRIO (mm)  \
# 0     False     False                             False
# 1     False     False                             False
# 2     False     False                             False
# 3     False     False                             False
# 4     False     False                             False
# ...     ...       ...                               ...
# 8755  False     False                              True
# 8756  False     False                              True
# 8757  False     False                              True
# 8758  False     False                              True
# 8759  False     False                              True
#
#       PRESSAO ATMOSFERICA AO NIVEL DA ESTACAO, HORARIA (mB)  \
# 0                                                 False
# 1                                                 False
# 2                                                 False
# 3                                                 False
# ...

# %%
df.isnull().sum()
# Out:
# Data                                                        0
# Hora UTC                                                    0
# PRECIPITAÇÃO TOTAL, HORÁRIO (mm)                         1291
# PRESSAO ATMOSFERICA AO NIVEL DA ESTACAO, HORARIA (mB)    1292
# PRESSÃO ATMOSFERICA MAX.NA HORA ANT. (AUT) (mB)          1304
# PRESSÃO ATMOSFERICA MIN. NA HORA ANT. (AUT) (mB)         1304
# RADIACAO GLOBAL (Kj/m²)                                  4791
# TEMPERATURA DO AR - BULBO SECO, HORARIA (°C)             1291
# TEMPERATURA DO PONTO DE ORVALHO (°C)                     1291
# TEMPERATURA MÁXIMA NA HORA ANT. (AUT) (°C)               1304
# TEMPERATURA MÍNIMA NA HORA ANT. (AUT) (°C)               1304
# TEMPERATURA ORVALHO MAX. NA HORA ANT. (AUT) (°C)         1304
# TEMPERATURA ORVALHO MIN. NA HORA ANT. (AUT) (°C)         1304
# UMIDADE REL. MAX. NA HORA ANT. (AUT) (%)                 1304
# UMIDADE REL. MIN. NA HORA ANT. (AUT) (%)                 1304
# ...

# %%
remover = df.dropna
remover
# Out:
# <bound method DataFrame.dropna of             Data  Hora UTC PRECIPITAÇÃO TOTAL, HORÁRIO (mm)  \
# 0     2023/01/01  0000 UTC                                0
# 1     2023/01/01  0100 UTC                                0
# 2     2023/01/01  0200 UTC                                0
# 3     2023/01/01  0300 UTC                                0
# 4     2023/01/01  0400 UTC                                0
# ...          ...       ...                              ...
# 8755  2023/12/31  1900 UTC                              NaN
# 8756  2023/12/31  2000 UTC                              NaN
# 8757  2023/12/31  2100 UTC                              NaN
# 8758  2023/12/31  2200 UTC                              NaN
# 8759  2023/12/31  2300 UTC                              NaN
#
#      PRESSAO ATMOSFERICA AO NIVEL DA ESTACAO, HORARIA (mB)  \
# 0                                                 955,2
# 1                                                 955,5
# ...

# %%
remover = df.dropna(axis=0, how='all')
remover
# Out:
#             Data  Hora UTC PRECIPITAÇÃO TOTAL, HORÁRIO (mm)  \
# 0     2023/01/01  0000 UTC                                0
# 1     2023/01/01  0100 UTC                                0
# 2     2023/01/01  0200 UTC                                0
# 3     2023/01/01  0300 UTC                                0
# 4     2023/01/01  0400 UTC                                0
# ...          ...       ...                              ...
# 8755  2023/12/31  1900 UTC                              NaN
# 8756  2023/12/31  2000 UTC                              NaN
# 8757  2023/12/31  2100 UTC                              NaN
# 8758  2023/12/31  2200 UTC                              NaN
# 8759  2023/12/31  2300 UTC                              NaN
#
#      PRESSAO ATMOSFERICA AO NIVEL DA ESTACAO, HORARIA (mB)  \
# 0                                                 955,2
# 1                                                 955,5
# 2                                                 955,2
# ...

# %%
df_substituido = df.replace('0', '-1')

# %%
df_substituido.head(9)
# Out:
#          Data  Hora UTC PRECIPITAÇÃO TOTAL, HORÁRIO (mm)  \
# 0  2023/01/01  0000 UTC                               -1
# 1  2023/01/01  0100 UTC                               -1
# 2  2023/01/01  0200 UTC                               -1
# 3  2023/01/01  0300 UTC                               -1
# 4  2023/01/01  0400 UTC                               -1
# 5  2023/01/01  0500 UTC                               -1
# 6  2023/01/01  0600 UTC                               -1
# 7  2023/01/01  0700 UTC                               -1
# 8  2023/01/01  0800 UTC                               -1
#
#   PRESSAO ATMOSFERICA AO NIVEL DA ESTACAO, HORARIA (mB)  \
# 0                                              955,2
# 1                                              955,5
# 2                                              955,2
# 3                                              954,8
# 4                                              954,4
# 5                                                954
# ...

# %%
df['Coluna1_normalizada'] = (df['UMIDADE RELATIVA DO AR, HORARIA (%)'] - df['UMIDADE RELATIVA DO AR, HORARIA (%)'].min()) / (df['UMIDADE RELATIVA DO AR, HORARIA (%)'].max() - df['UMIDADE RELATIVA DO AR, HORARIA (%)'].min())

# %%
df['Coluna1_normalizada'].head(20)
# Out:
# 0     0.976744
# 1     0.976744
# 2     0.976744
# 3     0.976744
# 4     0.976744
# 5     0.965116
# 6     0.976744
# 7     0.976744
# 8     0.976744
# 9     0.976744
# 10    0.941860
# 11    0.790698
# 12    0.755814
# 13    0.651163
# 14    0.627907
# 15    0.534884
# 16    0.534884
# 17    0.546512
# 18    0.523256
# 19    0.511628
# Name: Coluna1_normalizada, dtype: float64

# %%
import matplotlib.pyplot as plt
