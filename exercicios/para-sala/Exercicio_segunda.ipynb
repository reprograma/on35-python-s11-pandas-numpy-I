# %%
import pandas as pd

df = pd.read_csv('BRASILIA.CSV', delimiter=';',skiprows=8, encoding='latin1')

# %%
df.head(20)
# Out:
#           Data  Hora UTC PRECIPITAÇÃO TOTAL, HORÁRIO (mm)  \
# 0   2020/01/01  0000 UTC                                0
# 1   2020/01/01  0100 UTC                                0
# 2   2020/01/01  0200 UTC                                0
# 3   2020/01/01  0300 UTC                                0
# 4   2020/01/01  0400 UTC                                0
# 5   2020/01/01  0500 UTC                                0
# 6   2020/01/01  0600 UTC                                0
# 7   2020/01/01  0700 UTC                                0
# 8   2020/01/01  0800 UTC                               ,2
# 9   2020/01/01  0900 UTC                                0
# 10  2020/01/01  1000 UTC                                0
# 11  2020/01/01  1100 UTC                                0
# 12  2020/01/01  1200 UTC                                0
# 13  2020/01/01  1300 UTC                                0
# 14  2020/01/01  1400 UTC                                0
# ...

# %%
df_reduzido = df.head(20)

# %%
df_reduzido.sample(n=5)
# Out:
#             Data  Hora UTC PRECIPITAÇÃO TOTAL, HORÁRIO (mm)  \
# 423   2020/01/18  1500 UTC                                0
# 8691  2020/12/28  0300 UTC                                0
# 7270  2020/10/29  2200 UTC                                0
# 3770  2020/06/06  0200 UTC                                0
# 5706  2020/08/25  1800 UTC                                0
#
#      TEMPERATURA MÁXIMA NA HORA ANT. (AUT) (°C)
# 423                                          24
# 8691                                       20,3
# 7270                                       25,3
# 3770                                       19,7
# 5706                                       26,3

# %%
df_reduzido = df[['Data', 'Hora UTC', 'PRECIPITAÇÃO TOTAL, HORÁRIO (mm)', 'TEMPERATURA MÁXIMA NA HORA ANT. (AUT) (°C)']]

# %%
df_reduzido.head()
# Out:
#          Data  Hora UTC PRECIPITAÇÃO TOTAL, HORÁRIO (mm)  \
# 0  2020/01/01  0000 UTC                                0
# 1  2020/01/01  0100 UTC                                0
# 2  2020/01/01  0200 UTC                                0
# 3  2020/01/01  0300 UTC                                0
# 4  2020/01/01  0400 UTC                                0
#
#   TEMPERATURA MÁXIMA NA HORA ANT. (AUT) (°C)
# 0                                       20,2
# 1                                         20
# 2                                       20,1
# 3                                       20,2
# 4                                       19,8

# %%
df_reduzido.isnull()
# Out:
#        Data  Hora UTC  PRECIPITAÇÃO TOTAL, HORÁRIO (mm)  \
# 0     False     False                             False
# 1     False     False                             False
# 2     False     False                             False
# 3     False     False                             False
# 4     False     False                             False
# ...     ...       ...                               ...
# 8779  False     False                             False
# 8780  False     False                             False
# 8781  False     False                             False
# 8782  False     False                             False
# 8783  False     False                             False
#
#       TEMPERATURA MÁXIMA NA HORA ANT. (AUT) (°C)
# 0                                          False
# 1                                          False
# 2                                          False
# 3                                          False
# ...

# %%
df_substituido = df_reduzido.replace(';', ',', regex=True)

# %%
df_substituido
# Out:
#             Data  Hora UTC PRECIPITAÇÃO TOTAL, HORÁRIO (mm)  \
# 0     2020/01/01  0000 UTC                                0
# 1     2020/01/01  0100 UTC                                0
# 2     2020/01/01  0200 UTC                                0
# 3     2020/01/01  0300 UTC                                0
# 4     2020/01/01  0400 UTC                                0
# ...          ...       ...                              ...
# 8779  2020/12/31  1900 UTC                                0
# 8780  2020/12/31  2000 UTC                                0
# 8781  2020/12/31  2100 UTC                                0
# 8782  2020/12/31  2200 UTC                                0
# 8783  2020/12/31  2300 UTC                                0
#
#      TEMPERATURA MÁXIMA NA HORA ANT. (AUT) (°C)
# 0                                          20,2
# 1                                            20
# 2                                          20,1
# 3                                          20,2
# ...
